# %%
import os
from PIL import Image
import numpy as np
import random
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms

# Set up the data directory
data_dir = 'subject codes/'

# Load image paths and labels
image_pairs = [
    (os.path.join(data_dir, f), f[:7].upper()) 
    for f in os.listdir(data_dir) 
    if f.lower().endswith(('.png', '.jpg', '.jpeg')) and len(f[:7]) == 7 and all(c.isalnum() for c in f[:7])
]

# Validate labels
def validate_label(label):
    if len(label) != 7 or not all(c.isalnum() for c in label):
        raise ValueError(f"Invalid subject code: {label}")
    return label

cleaned_pairs = [(path, validate_label(label)) for path, label in image_pairs]

# %%
cleaned_pairs
# Out:
# [('subject codes/19AI303.jpg', '19AI303'),
#  ('subject codes/19AI303 (2).jpg', '19AI303'),
#  ('subject codes/19AI303 (3).jpg', '19AI303'),
#  ('subject codes/19AI303 (4).jpg', '19AI303'),
#  ('subject codes/19AI303 (5).jpg', '19AI303'),
#  ('subject codes/19AI303 (6).jpg', '19AI303'),
#  ('subject codes/19AI303 (7).jpg', '19AI303'),
#  ('subject codes/19AI303 (8).jpg', '19AI303'),
#  ('subject codes/19AI303 (9).jpg', '19AI303'),
#  ('subject codes/19AI303 (10).jpg', '19AI303'),
#  ('subject codes/19AI401.jpg', '19AI401'),
#  ('subject codes/19AI403.jpg', '19AI403'),
#  ('subject codes/19AI403 (2).jpg', '19AI403'),
#  ('subject codes/19AI403 (3).jpg', '19AI403'),
#  ('subject codes/19AI403 (4).jpg', '19AI403'),
#  ('subject codes/19AI403 (5).jpg', '19AI403'),
#  ('subject codes/19AI403 (6).jpg', '19AI403'),
#  ('subject codes/19AI403 (7).jpg', '19AI403'),
#  ('subject codes/19AI403 (8).jpg', '19AI403'),
#  ('subject codes/19AI403 (9).jpg', '19AI403'),
#  ('subject codes/19AI403 (10).jpg', '19AI403'),
#  ('subject codes/19AI403 (11).jpg', '19AI403'),
#  ('subject codes/19AI403 (12).jpg', '19AI403'),
#  ('subject codes/19AI403 (13).jpg', '19AI403'),
#  ('subject codes/19AI405.jpg', '19AI405'),
#  ('subject codes/19AI405 (2).jpg', '19AI405'),
#  ('subject codes/19AI408.jpg', '19AI408'),
#  ('subject codes/19AI409.jpg', '19AI409'),
#  ('subject codes/19AI409 (2).jpg', '19AI409'),
#  ('subject codes/19AI409 (3).jpg', '19AI409'),
#  ('subject codes/19AI409 (4).jpg', '19AI409'),
#  ('subject codes/19AI409 (5).jpg', '19AI409'),
#  ('subject codes/19AI410.jpg', '19AI410'),
#  ('subject codes/19AI410 (2).jpg', '19AI410'),
#  ('subject codes/19AI410 (3).jpg', '19AI410'),
#  ('subject codes/19AI410 (4).jpg', '19AI410'),
#  ('subject codes/19AI410 (5).jpg', '19AI410'),
#  ('subject codes/19AI410 (6).jpg', '19AI410'),
#  ('subject codes/19AI413.jpg', '19AI413'),
#  ('subject codes/19AI414.jpg', '19AI414'),
#  ('subject codes/19AI414 (2).jpg', '19AI414'),
#  ('subject codes/19AI414 (3).jpg', '19AI414'),
#  ('subject codes/19AI414 (4).jpg', '19AI414'),
#  ('subject codes/19AI414 (5).jpg', '19AI414'),
#  ('subject codes/19AI414 (6).jpg', '19AI414'),
#  ('subject codes/19AI414 (7).jpg', '19AI414'),
#  ('subject codes/19AI414 (8).jpg', '19AI414'),
#  ('subject codes/19AI414 (9).jpg', '19AI414'),
#  ('subject codes/19AI414 (10).jpg', '19AI414'),
#  ('subject codes/19AI414 (11).jpg', '19AI414'),
#  ('subject codes/19AI414 (12).jpg', '19AI414'),
#  ('subject codes/19AI512.jpg', '19AI512'),
#  ('subject codes/19AI512 (2).jpg', '19AI512'),
#  ('subject codes/19AI512 (3).jpg', '19AI512'),
#  ('subject codes/19AI512 (4).jpg', '19AI512'),
#  ('subject codes/19AI512 (5).jpg', '19AI512'),
#  ('subject codes/19AI512 (6).jpg', '19AI512'),
#  ('subject codes/19AI512C.jpg', '19AI512'),
#  ('subject codes/19AI512C (2).jpg', '19AI512'),
#  ('subject codes/19AI512C (3).jpg', '19AI512'),
#  ('subject codes/19AI512C (4).jpg', '19AI512'),
#  ('subject codes/19AI512C (5).jpg', '19AI512'),
#  ('subject codes/19AI512C (6).jpg', '19AI512'),
#  ('subject codes/19AI512C (7).jpg', '19AI512'),
#  ('subject codes/19AI512C (8).jpg', '19AI512'),
#  ('subject codes/19AI512C (9).jpg', '19AI512'),
#  ('subject codes/19AI512C (10).jpg', '19AI512'),
#  ('subject codes/19AI512C (11).jpg', '19AI512'),
#  ('subject codes/19AI512C (12).jpg', '19AI512'),
#  ('subject codes/19AI512C (13).jpg', '19AI512'),
#  ('subject codes/19AI512C (14).jpg', '19AI512'),
#  ('subject codes/19AI513.jpg', '19AI513'),
#  ('subject codes/19AI513 (2).jpg', '19AI513'),
#  ('subject codes/19AI513 (3).jpg', '19AI513'),
#  ('subject codes/19AI521.jpg', '19AI521'),
#  ('subject codes/19AI541.jpg', '19AI541'),
#  ('subject codes/19AI541 (2).jpg', '19AI541'),
#  ('subject codes/19AI541 (3).jpg', '19AI541'),
#  ('subject codes/19AI541 (4).jpg', '19AI541'),
#  ('subject codes/19AI541 (5).jpg', '19AI541'),
#  ('subject codes/19AI541 (6).jpg', '19AI541'),
#  ('subject codes/19AI541 (7).jpg', '19AI541'),
#  ('subject codes/19AI541 (8).jpg', '19AI541'),
#  ('subject codes/19AI541 (9).jpg', '19AI541'),
#  ('subject codes/19AI541 (10).jpg', '19AI541'),
#  ('subject codes/19AI541 (11).jpg', '19AI541'),
#  ('subject codes/19AI546.jpg', '19AI546'),
#  ('subject codes/19AI546 (2).jpg', '19AI546'),
#  ('subject codes/19AI546 (3).jpg', '19AI546'),
#  ('subject codes/19AI546 (4).jpg', '19AI546'),
#  ('subject codes/19AI546 (5).jpg', '19AI546'),
#  ('subject codes/19AI547.jpg', '19AI547'),
#  ('subject codes/19AI547 (2).jpg', '19AI547'),
#  ('subject codes/19AI547 (3).jpg', '19AI547'),
#  ('subject codes/19AI547 (4).jpg', '19AI547'),
#  ('subject codes/19AI547 (5).jpg', '19AI547'),
#  ('subject codes/19AI547 (6).jpg', '19AI547'),
#  ('subject codes/19AI550.jpg', '19AI550'),
#  ('subject codes/19AI550 (2).jpg', '19AI550'),
#  ('subject codes/19AI550 (3).jpg', '19AI550'),
#  ('subject codes/19AI550 (4).jpg', '19AI550'),
#  ('subject codes/19AI550 (5).jpg', '19AI550'),
#  ('subject codes/19AI550 (6).jpg', '19AI550'),
#  ('subject codes/19AI550 (7).jpg', '19AI550'),
#  ('subject codes/19AM509.jpg', '19AM509'),
#  ('subject codes/19AM509 (2).jpg', '19AM509'),
#  ('subject codes/19AM509 (3).jpg', '19AM509'),
#  ('subject codes/19CS305.jpg', '19CS305'),
#  ('subject codes/19CS305 (2).jpg', '19CS305'),
#  ('subject codes/19CS305 (3).jpg', '19CS305'),
#  ('subject codes/19CS305 (4).jpg', '19CS305'),
#  ('subject codes/19CS305 (5).jpg', '19CS305'),
#  ('subject codes/19CS305 (6).jpg', '19CS305'),
#  ('subject codes/19CS305 (7).jpg', '19CS305'),
#  ('subject codes/19CS305 (8).jpg', '19CS305'),
#  ('subject codes/19CS305 (9).jpg', '19CS305'),
#  ('subject codes/19CS404.jpg', '19CS404'),
#  ('subject codes/19CS404 (2).jpg', '19CS404'),
#  ('subject codes/19CS404 (3).jpg', '19CS404'),
#  ('subject codes/19CS404 (4).jpg', '19CS404'),
#  ('subject codes/19CS404 (5).jpg', '19CS404'),
#  ('subject codes/19CS404 (6).jpg', '19CS404'),
#  ('subject codes/19CS404 (7).jpg', '19CS404'),
#  ('subject codes/19CS405.jpg', '19CS405'),
#  ('subject codes/19CS406.jpg', '19CS406'),
#  ('subject codes/19CS406 (2).jpg', '19CS406'),
#  ('subject codes/19CS406 (3).jpg', '19CS406'),
#  ('subject codes/19CS407.jpg', '19CS407'),
#  ('subject codes/19CS407 (2).jpg', '19CS407'),
#  ('subject codes/19CS407 (3).jpg', '19CS407'),
#  ('subject codes/19CS407 (4).jpg', '19CS407'),
#  ('subject codes/19CS407 (5).jpg', '19CS407'),
#  ('subject codes/19CS407 (6).jpg', '19CS407'),
#  ('subject codes/19CS409.jpg', '19CS409'),
#  ('subject codes/19CS409 (2).jpg', '19CS409'),
#  ('subject codes/19CS409 (3).jpg', '19CS409'),
#  ('subject codes/19CS411.jpg', '19CS411'),
#  ('subject codes/19CS411 (2).jpg', '19CS411'),
#  ('subject codes/19CS411 (3).jpg', '19CS411'),
#  ('subject codes/19CS412.jpg', '19CS412'),
#  ('subject codes/19CS412 (2).jpg', '19CS412'),
#  ('subject codes/19CS412 (3).jpg', '19CS412'),
#  ('subject codes/19CS412 (4).jpg', '19CS412'),
#  ('subject codes/19CS412 (5).jpg', '19CS412'),
#  ('subject codes/19CS412 (6).jpg', '19CS412'),
#  ('subject codes/19CS413 (2).jpg', '19CS413'),
#  ('subject codes/19CS413 (3).jpg', '19CS413'),
#  ('subject codes/19CS413 (4).jpg', '19CS413'),
#  ('subject codes/19CS413 (5).jpg', '19CS413'),
#  ('subject codes/19CS413 (6).jpg', '19CS413'),
#  ('subject codes/19CS413 (7).jpg', '19CS413'),
#  ('subject codes/19CS413 (8).jpg', '19CS413'),
#  ('subject codes/19CS413 (9).jpg', '19CS413'),
#  ('subject codes/19CS413 (10).jpg', '19CS413'),
#  ('subject codes/19CS413 (11).jpg', '19CS413'),
#  ('subject codes/19CS413 (12).jpg', '19CS413'),
#  ('subject codes/19CS413 (13).jpg', '19CS413'),
#  ('subject codes/19CS414.jpg', '19CS414'),
#  ('subject codes/19CS414 (2).jpg', '19CS414'),
#  ('subject codes/19CS414 (3).jpg', '19CS414'),
#  ('subject codes/19CS414 (4).jpg', '19CS414'),
#  ('subject codes/19CS414 (5).jpg', '19CS414'),
#  ('subject codes/19CS414 (6).jpg', '19CS414'),
#  ('subject codes/19CS414 (7).jpg', '19CS414'),
#  ('subject codes/19CS414 (8).jpg', '19CS414'),
#  ('subject codes/19CS414 (9).jpg', '19CS414'),
#  ('subject codes/19CS414 (10).jpg', '19CS414'),
#  ('subject codes/19CS414 (11).jpg', '19CS414'),
#  ('subject codes/19CS414 (12).jpg', '19CS414'),
#  ('subject codes/19CS414 (13).jpg', '19CS414'),
#  ('subject codes/19CS414 (14).jpg', '19CS414'),
#  ('subject codes/19CS414 (15).jpg', '19CS414'),
#  ('subject codes/19CS414 (16).jpg', '19CS414'),
#  ('subject codes/19CS415.jpg', '19CS415'),
#  ('subject codes/19CS415 (4).jpg', '19CS415'),
#  ('subject codes/19CS415 (5).jpg', '19CS415'),
#  ('subject codes/19CS415 (6).jpg', '19CS415'),
#  ('subject codes/19CS415 (7).jpg', '19CS415'),
#  ('subject codes/19CS415 (8).jpg', '19CS415'),
#  ('subject codes/19CS415 (9).jpg', '19CS415'),
#  ('subject codes/19CS415 (10).jpg', '19CS415'),
#  ('subject codes/19CS415 (11).jpg', '19CS415'),
#  ('subject codes/19CS415 (12).jpg', '19CS415'),
#  ('subject codes/19CS416.jpg', '19CS416'),
#  ('subject codes/19CS417.jpg', '19CS417'),
#  ('subject codes/19CS417 (2).jpg', '19CS417'),
#  ('subject codes/19CS417 (3).jpg', '19CS417'),
#  ('subject codes/19CS417 (4).jpg', '19CS417'),
#  ('subject codes/19CS417 (5).jpg', '19CS417'),
#  ('subject codes/19CS418 (2).jpg', '19CS418'),
#  ('subject codes/19CS418 (3).jpg', '19CS418'),
#  ('subject codes/19CS418_FLIP.jpg', '19CS418'),
#  ('subject codes/19CS419.jpg', '19CS419'),
#  ('subject codes/19CS420.jpg', '19CS420'),
#  ('subject codes/19CS420 (2).jpg', '19CS420'),
#  ('subject codes/19CS420 (3).jpg', '19CS420'),
#  ('subject codes/19CS421.jpg', '19CS421'),
#  ('subject codes/19CS504.jpg', '19CS504'),
#  ('subject codes/19CS504 (2).jpg', '19CS504'),
#  ('subject codes/19CS504 (3).jpg', '19CS504'),
#  ('subject codes/19CS504 (4).jpg', '19CS504'),
#  ('subject codes/19CS504 (5).jpg', '19CS504'),
#  ('subject codes/19CS504 (6).jpg', '19CS504'),
#  ('subject codes/19CS504 (7).jpg', '19CS504'),
#  ('subject codes/19CS504 (8).jpg', '19CS504'),
#  ('subject codes/19CS504 (9).jpg', '19CS504'),
#  ('subject codes/19CS509.jpg', '19CS509'),
#  ('subject codes/19CS515.jpg', '19CS515'),
#  ('subject codes/19CS545.jpg', '19CS545'),
#  ('subject codes/19CS545 (2).jpg', '19CS545'),
#  ('subject codes/19CS545 (3).jpg', '19CS545'),
#  ('subject codes/19CS545 (4).jpg', '19CS545'),
#  ('subject codes/19CS545 (5).jpg', '19CS545'),
#  ('subject codes/19CS547.jpg', '19CS547'),
#  ('subject codes/19CS565.jpg', '19CS565'),
#  ('subject codes/19EC406.jpg', '19EC406'),
#  ('subject codes/19EC410.jpg', '19EC410'),
#  ('subject codes/19EC519.jpg', '19EC519'),
#  ('subject codes/19EC519 (2).jpg', '19EC519'),
#  ('subject codes/19EC522.jpg', '19EC522'),
#  ('subject codes/19EC522 (4).jpg', '19EC522'),
#  ('subject codes/19EC522 (5).jpg', '19EC522'),
#  ('subject codes/19EC522 (6).jpg', '19EC522'),
#  ('subject codes/19EE309.jpg', '19EE309'),
#  ('subject codes/19EE404.jpg', '19EE404'),
#  ('subject codes/19EE404 (2).jpg', '19EE404'),
#  ('subject codes/19EE404 (3).jpg', '19EE404'),
#  ('subject codes/19EE404 (4).jpg', '19EE404'),
#  ('subject codes/19EE404 (5).jpg', '19EE404'),
#  ('subject codes/19EE404 (6).jpg', '19EE404'),
#  ('subject codes/19EE404 (7).jpg', '19EE404'),
#  ('subject codes/19EE404 (8).jpg', '19EE404'),
#  ('subject codes/19EE404 (9).jpg', '19EE404'),
#  ('subject codes/19EE404 (10).jpg', '19EE404'),
#  ('subject codes/19EE404 (11).jpg', '19EE404'),
#  ('subject codes/19EE404 (12).jpg', '19EE404'),
#  ('subject codes/19EE404 (13).jpg', '19EE404'),
#  ('subject codes/19EE404 (14).jpg', '19EE404'),
#  ('subject codes/19EE404 (15).jpg', '19EE404'),
#  ('subject codes/19EE404 (16).jpg', '19EE404'),
#  ('subject codes/19EE404 (17).jpg', '19EE404'),
#  ('subject codes/19EE404 (18).jpg', '19EE404'),
#  ('subject codes/19EE404 (19).jpg', '19EE404'),
#  ('subject codes/19EE404 (20).jpg', '19EE404'),
#  ('subject codes/19EE404 (21).jpg', '19EE404'),
#  ('subject codes/19EE404 (22).jpg', '19EE404'),
#  ('subject codes/19EE404 (23).jpg', '19EE404'),
#  ('subject codes/19EE404 (24).jpg', '19EE404'),
#  ('subject codes/19EE494.jpg', '19EE494'),
#  ('subject codes/19IT406.jpg', '19IT406'),
#  ('subject codes/19MA220.jpg', '19MA220'),
#  ('subject codes/19MA220 (2).jpg', '19MA220'),
#  ('subject codes/19MA220 (3).jpg', '19MA220'),
#  ('subject codes/19MA220 (4).jpg', '19MA220'),
#  ('subject codes/19MA220 (5).jpg', '19MA220'),
#  ('subject codes/19MA220 (6).jpg', '19MA220'),
#  ('subject codes/19MA220 (7).jpg', '19MA220'),
#  ('subject codes/19MA220 (8).jpg', '19MA220'),
#  ('subject codes/19MA220 (9).jpg', '19MA220'),
#  ('subject codes/19MA220 (10).jpg', '19MA220'),
#  ('subject codes/19MA220 (11).jpg', '19MA220'),
#  ('subject codes/19MA220 (12).jpg', '19MA220'),
#  ('subject codes/19MA221.jpg', '19MA221'),
#  ('subject codes/19MS154.jpg', '19MS154'),
#  ('subject codes/19MS154 (2).jpg', '19MS154'),
#  ('subject codes/19MS154 (3).jpg', '19MS154'),
#  ('subject codes/19MS155.jpg', '19MS155'),
#  ('subject codes/19MS155 (2).jpg', '19MS155'),
#  ('subject codes/19MS155 (3).jpg', '19MS155'),
#  ('subject codes/19MS155 (4).jpg', '19MS155'),
#  ('subject codes/19MS155 (5).jpg', '19MS155'),
#  ('subject codes/19MS156.jpg', '19MS156'),
#  ('subject codes/19MS156 (2).jpg', '19MS156'),
#  ('subject codes/19MS156 (3).jpg', '19MS156'),
#  ('subject codes/19MS156 (4).jpg', '19MS156'),
#  ('subject codes/19MS156 (5).jpg', '19MS156'),
#  ('subject codes/19MS156 (6).jpg', '19MS156'),
#  ('subject codes/19MS156 (7).jpg', '19MS156'),
#  ('subject codes/19MS156 (8).jpg', '19MS156'),
#  ('subject codes/19AI403 (14).jpg', '19AI403'),
#  ('subject codes/19AI403 (15).jpg', '19AI403'),
#  ('subject codes/19AI405 (3).jpg', '19AI405'),
#  ('subject codes/19AI406.jpg', '19AI406'),
#  ('subject codes/19AI407.jpg', '19AI407'),
#  ('subject codes/19AI407 (2).jpg', '19AI407'),
#  ('subject codes/19AI407 (3).jpg', '19AI407'),
#  ('subject codes/19AI407 (4).jpg', '19AI407'),
#  ('subject codes/19AI409 (6).jpg', '19AI409'),
#  ('subject codes/19AI410 (7).jpg', '19AI410'),
#  ('subject codes/19AI410 (8).jpg', '19AI410'),
#  ('subject codes/19AI410 (9).jpg', '19AI410'),
#  ('subject codes/19AI410 (10).jpg', '19AI410'),
#  ('subject codes/19AI410 (11).jpg', '19AI410'),
#  ('subject codes/19AI411.jpg', '19AI411'),
#  ('subject codes/19AI412.jpg', '19AI412'),
#  ('subject codes/19AI412 (2).jpg', '19AI412'),
#  ('subject codes/19AI413 (2).jpg', '19AI413'),
#  ('subject codes/19AI413 (3).jpg', '19AI413'),
#  ('subject codes/19AI512 (7).jpg', '19AI512'),
#  ('subject codes/19AI512 (8).jpg', '19AI512'),
#  ('subject codes/19AI513 (4).jpg', '19AI513'),
#  ('subject codes/19AI513 (5).jpg', '19AI513'),
#  ('subject codes/19AI513 (6).jpg', '19AI513'),
#  ('subject codes/19AI513 (7).jpg', '19AI513'),
#  ('subject codes/19AI545.jpg', '19AI545'),
#  ('subject codes/19AI550 (8).jpg', '19AI550'),
#  ('subject codes/19CS305 (10).jpg', '19CS305'),
#  ('subject codes/19CS404 (8).jpg', '19CS404'),
#  ('subject codes/19CS404 (9).jpg', '19CS404'),
#  ('subject codes/19CS404 (10).jpg', '19CS404'),
#  ('subject codes/19CS406 (4).jpg', '19CS406'),
#  ('subject codes/19CS406 (5).jpg', '19CS406'),
#  ('subject codes/19CS406 (6).jpg', '19CS406'),
#  ('subject codes/19CS407 (7).jpg', '19CS407'),
#  ('subject codes/19CS407 (8).jpg', '19CS407'),
#  ('subject codes/19CS408.jpg', '19CS408'),
#  ('subject codes/19CS409 (4).jpg', '19CS409'),
#  ('subject codes/19CS409 (5).jpg', '19CS409'),
#  ('subject codes/19CS409 (6).jpg', '19CS409'),
#  ('subject codes/19CS413 (14).jpg', '19CS413'),
#  ('subject codes/19CS415 (13).jpg', '19CS415'),
#  ('subject codes/19CS417 (6).jpg', '19CS417'),
#  ('subject codes/19CS417 (7).jpg', '19CS417'),
#  ('subject codes/19CS504 (10).jpg', '19CS504'),
#  ('subject codes/19CS570.jpg', '19CS570'),
#  ('subject codes/19CS570 (2).jpg', '19CS570'),
#  ('subject codes/19EE305.jpg', '19EE305'),
#  ('subject codes/19EE305 (2).jpg', '19EE305'),
#  ('subject codes/19EE305 (3).jpg', '19EE305'),
#  ('subject codes/19EE305 (4).jpg', '19EE305'),
#  ('subject codes/19EE309 (2).jpg', '19EE309'),
#  ('subject codes/19MS154 (4).jpg', '19MS154'),
#  ('subject codes/19MS155 (6).jpg', '19MS155'),
#  ('subject codes/19MS155 (7).jpg', '19MS155'),
#  ('subject codes/19MS156 (9).jpg', '19MS156'),
#  ('subject codes/19MS156 (10).jpg', '19MS156'),
#  ('subject codes/19AI210.jpg', '19AI210'),
#  ('subject codes/19AI212.jpg', '19AI212'),
#  ('subject codes/19AI301.jpg', '19AI301'),
#  ('subject codes/19AI303 (11).jpg', '19AI303'),
#  ('subject codes/19AI303 (12).jpg', '19AI303'),
#  ('subject codes/19AI309.jpg', '19AI309'),
#  ('subject codes/19AI403 (16).jpg', '19AI403'),
#  ('subject codes/19AI403 (17).jpg', '19AI403'),
#  ('subject codes/19AI403 (18).jpg', '19AI403'),
#  ('subject codes/19AI403 (19).jpg', '19AI403'),
#  ('subject codes/19AI403 (20).jpg', '19AI403'),
#  ('subject codes/19AI403 (21).jpg', '19AI403'),
#  ('subject codes/19AI403 (22).jpg', '19AI403'),
#  ('subject codes/19AI403 (23).jpg', '19AI403'),
#  ('subject codes/19AI403 (24).jpg', '19AI403'),
#  ('subject codes/19AI403 (25).jpg', '19AI403'),
#  ('subject codes/19AI403 (26).jpg', '19AI403'),
#  ('subject codes/19AI405 (4).jpg', '19AI405'),
#  ('subject codes/19AI405 (5).jpg', '19AI405'),
#  ('subject codes/19AI406 (2).jpg', '19AI406'),
#  ('subject codes/19AI407 (5).jpg', '19AI407'),
#  ('subject codes/19AI407 (6).jpg', '19AI407'),
#  ('subject codes/19AI407 (7).jpg', '19AI407'),
#  ('subject codes/19AI409 (7).jpg', '19AI409'),
#  ('subject codes/19AI410 (12).jpg', '19AI410'),
#  ('subject codes/19AI410 (13).jpg', '19AI410'),
#  ('subject codes/19AI410 (14).jpg', '19AI410'),
#  ('subject codes/19AI410 (15).jpg', '19AI410'),
#  ('subject codes/19AI410 (16).jpg', '19AI410'),
#  ('subject codes/19AI410 (17).jpg', '19AI410'),
#  ('subject codes/19AI410 (18).jpg', '19AI410'),
#  ('subject codes/19AI410 (19).jpg', '19AI410'),
#  ('subject codes/19AI410 (20).jpg', '19AI410'),
#  ('subject codes/19AI410 (21).jpg', '19AI410'),
#  ('subject codes/19AI410 (22).jpg', '19AI410'),
#  ('subject codes/19AI410 (23).jpg', '19AI410'),
#  ('subject codes/19AI410 (24).jpg', '19AI410'),
#  ('subject codes/19AI410 (25).jpg', '19AI410'),
#  ('subject codes/19AI410 (26).jpg', '19AI410'),
#  ('subject codes/19AI410 (27).jpg', '19AI410'),
#  ('subject codes/19AI410 (28).jpg', '19AI410'),
#  ('subject codes/19AI411 (2).jpg', '19AI411'),
#  ('subject codes/19AI412 (3).jpg', '19AI412'),
#  ('subject codes/19AI412 (4).jpg', '19AI412'),
#  ('subject codes/19AI412 (5).jpg', '19AI412'),
#  ('subject codes/19AI413 (4).jpg', '19AI413'),
#  ('subject codes/19AI414 (13).jpg', '19AI414'),
#  ('subject codes/19AI414 (14).jpg', '19AI414'),
#  ('subject codes/19AI414 (15).jpg', '19AI414'),
#  ('subject codes/19AI414 (16).jpg', '19AI414'),
#  ('subject codes/19AI512 (9).jpg', '19AI512'),
#  ('subject codes/19AI512 C.jpg', '19AI512'),
#  ('subject codes/19AI541 (12).jpg', '19AI541'),
#  ('subject codes/19AI541 (13).jpg', '19AI541'),
#  ('subject codes/19AI545 (2).jpg', '19AI545'),
#  ('subject codes/19AM508.jpg', '19AM508'),
#  ('subject codes/19AM508 (2).jpg', '19AM508'),
#  ('subject codes/19AM508 (3).jpg', '19AM508'),
#  ('subject codes/19AM509 (4).jpg', '19AM509'),
#  ('subject codes/19cs404 (13).jpg', '19CS404'),
#  ('subject codes/19cs408 (12).jpg', '19CS408'),
#  ('subject codes/19cs409 (17).jpg', '19CS409'),
#  ('subject codes/19CS305 (11).jpg', '19CS305'),
#  ('subject codes/19CS305 (12).jpg', '19CS305'),
#  ('subject codes/19CS305 (13).jpg', '19CS305'),
#  ('subject codes/19CS305 (14).jpg', '19CS305'),
#  ('subject codes/19CS305 (15).jpg', '19CS305'),
#  ('subject codes/19CS306.jpg', '19CS306'),
#  ('subject codes/19CS404 (11).jpg', '19CS404'),
#  ('subject codes/19CS404 (12).jpg', '19CS404'),
#  ('subject codes/19CS404 (13).jpg', '19CS404'),
#  ('subject codes/19CS404 (14).jpg', '19CS404'),
#  ('subject codes/19CS404 (15).jpg', '19CS404'),
#  ('subject codes/19CS404 (16).jpg', '19CS404'),
#  ('subject codes/19CS404 (17).jpg', '19CS404'),
#  ('subject codes/19CS404 (18).jpg', '19CS404'),
#  ('subject codes/19CS404 (19).jpg', '19CS404'),
#  ('subject codes/19CS404 (20).jpg', '19CS404'),
#  ('subject codes/19CS404 (21).jpg', '19CS404'),
#  ('subject codes/19CS404 (22).jpg', '19CS404'),
#  ('subject codes/19CS404 (23).jpg', '19CS404'),
#  ('subject codes/19CS404 (24).jpg', '19CS404'),
#  ('subject codes/19CS404 (25).jpg', '19CS404'),
#  ('subject codes/19CS404 (26).jpg', '19CS404'),
#  ('subject codes/19CS404 (27).jpg', '19CS404'),
#  ('subject codes/19CS404 (28).jpg', '19CS404'),
#  ('subject codes/19CS405 (2).jpg', '19CS405'),
#  ('subject codes/19CS405 (3).jpg', '19CS405'),
#  ('subject codes/19CS405 (4).jpg', '19CS405'),
#  ('subject codes/19CS405 (5).jpg', '19CS405'),
#  ('subject codes/19CS405 (6).jpg', '19CS405'),
#  ('subject codes/19CS405 (7).jpg', '19CS405'),
#  ('subject codes/19CS405 (8).jpg', '19CS405'),
#  ('subject codes/19CS405 (9).jpg', '19CS405'),
#  ('subject codes/19CS405 (10).jpg', '19CS405'),
#  ('subject codes/19CS405 (11).jpg', '19CS405'),
#  ('subject codes/19CS405 (12).jpg', '19CS405'),
#  ('subject codes/19CS405 (13).jpg', '19CS405'),
#  ('subject codes/19CS405 (14).jpg', '19CS405'),
#  ('subject codes/19CS406 (7).jpg', '19CS406'),
#  ('subject codes/19CS406 (8).jpg', '19CS406'),
#  ('subject codes/19CS406 (9).jpg', '19CS406'),
#  ('subject codes/19CS406 (10).jpg', '19CS406'),
#  ('subject codes/19CS406 (11).jpg', '19CS406'),
#  ('subject codes/19CS406 (12).jpg', '19CS406'),
#  ('subject codes/19CS406 (13).jpg', '19CS406'),
#  ('subject codes/19CS406 (14).jpg', '19CS406'),
#  ('subject codes/19CS406 (15).jpg', '19CS406'),
#  ('subject codes/19CS406 (16).jpg', '19CS406'),
#  ('subject codes/19CS406 (17).jpg', '19CS406'),
#  ('subject codes/19CS406 (18).jpg', '19CS406'),
#  ('subject codes/19CS406 (19).jpg', '19CS406'),
#  ('subject codes/19CS406 (20).jpg', '19CS406'),
#  ('subject codes/19CS406 (21).jpg', '19CS406'),
#  ('subject codes/19CS406 (22).jpg', '19CS406'),
#  ('subject codes/19CS407 (9).jpg', '19CS407'),
#  ('subject codes/19CS407 (10).jpg', '19CS407'),
#  ('subject codes/19CS407 (11).jpg', '19CS407'),
#  ('subject codes/19CS407 (12).jpg', '19CS407'),
#  ('subject codes/19CS407 (13).jpg', '19CS407'),
#  ('subject codes/19CS407 (14).jpg', '19CS407'),
#  ('subject codes/19CS407 (15).jpg', '19CS407'),
#  ('subject codes/19CS407 (16).jpg', '19CS407'),
#  ('subject codes/19CS407 (17).jpg', '19CS407'),
#  ('subject codes/19CS407 (18).jpg', '19CS407'),
#  ('subject codes/19CS408 (2).jpg', '19CS408'),
#  ('subject codes/19CS408 (3).jpg', '19CS408'),
#  ('subject codes/19CS408 (4).jpg', '19CS408'),
#  ('subject codes/19CS408 (5).jpg', '19CS408'),
#  ('subject codes/19CS408 (6).jpg', '19CS408'),
#  ('subject codes/19CS408 (7).jpg', '19CS408'),
#  ('subject codes/19CS408 (8).jpg', '19CS408'),
#  ('subject codes/19CS408 (9).jpg', '19CS408'),
#  ('subject codes/19CS408 (10).jpg', '19CS408'),
#  ('subject codes/19CS408 (11).jpg', '19CS408'),
#  ('subject codes/19CS408 (13).jpg', '19CS408'),
#  ('subject codes/19CS408 (14).jpg', '19CS408'),
#  ('subject codes/19CS408 (15).jpg', '19CS408'),
#  ('subject codes/19CS408 (16).jpg', '19CS408'),
#  ('subject codes/19CS408 (17).jpg', '19CS408'),
#  ('subject codes/19CS408 (18).jpg', '19CS408'),
#  ('subject codes/19CS408 (19).jpg', '19CS408'),
#  ('subject codes/19CS409 (7).jpg', '19CS409'),
#  ('subject codes/19CS409 (8).jpg', '19CS409'),
#  ('subject codes/19CS409 (9).jpg', '19CS409'),
#  ('subject codes/19CS409 (10).jpg', '19CS409'),
#  ('subject codes/19CS409 (11).jpg', '19CS409'),
#  ('subject codes/19CS409 (12).jpg', '19CS409'),
#  ('subject codes/19CS409 (13).jpg', '19CS409'),
#  ('subject codes/19CS409 (14).jpg', '19CS409'),
#  ('subject codes/19CS409 (15).jpg', '19CS409'),
#  ('subject codes/19CS409 (16).jpg', '19CS409'),
#  ('subject codes/19CS409 (17).jpg', '19CS409'),
#  ('subject codes/19CS409 (18).jpg', '19CS409'),
#  ('subject codes/19CS409 (19).jpg', '19CS409'),
#  ('subject codes/19CS409 (20).jpg', '19CS409'),
#  ('subject codes/19CS409 (21).jpg', '19CS409'),
#  ('subject codes/19CS409 (22).jpg', '19CS409'),
#  ('subject codes/19CS409 (23).jpg', '19CS409'),
#  ('subject codes/19CS409 (24).jpg', '19CS409'),
#  ('subject codes/19CS409 (25).jpg', '19CS409'),
#  ('subject codes/19CS409 (26).jpg', '19CS409'),
#  ('subject codes/19CS409 (27).jpg', '19CS409'),
#  ('subject codes/19CS410.jpg', '19CS410'),
#  ('subject codes/19CS411 (4).jpg', '19CS411'),
#  ('subject codes/19CS414 (17).jpg', '19CS414'),
#  ('subject codes/19CS415 (14).jpg', '19CS415'),
#  ('subject codes/19CS415 (15).jpg', '19CS415'),
#  ('subject codes/19CS415 (16).jpg', '19CS415'),
#  ('subject codes/19CS415 (17).jpg', '19CS415'),
#  ('subject codes/19CS415 (18).jpg', '19CS415'),
#  ('subject codes/19CS415 (19).jpg', '19CS415'),
#  ('subject codes/19CS415 (20).jpg', '19CS415'),
#  ('subject codes/19CS415 (21).jpg', '19CS415'),
#  ('subject codes/19CS417 (8).jpg', '19CS417'),
#  ('subject codes/19CS417 (9).jpg', '19CS417'),
#  ('subject codes/19CS418 (4).jpg', '19CS418'),
#  ('subject codes/19CS418 (5).jpg', '19CS418'),
#  ('subject codes/19CS418 (6).jpg', '19CS418'),
#  ('subject codes/19CS418 (7).jpg', '19CS418'),
#  ('subject codes/19CS420 (4).jpg', '19CS420'),
#  ('subject codes/19CS420 (5).jpg', '19CS420'),
#  ('subject codes/19CS420 (6).jpg', '19CS420'),
#  ('subject codes/19CS420 (7).jpg', '19CS420'),
#  ('subject codes/19CS504 (11).jpg', '19CS504'),
#  ('subject codes/19CS514.jpg', '19CS514'),
#  ('subject codes/19CS542.jpg', '19CS542'),
#  ('subject codes/19CS570 (3).jpg', '19CS570'),
#  ('subject codes/19CS570 (4).jpg', '19CS570'),
#  ('subject codes/19CS579.jpg', '19CS579'),
#  ('subject codes/19CS579 (2).jpg', '19CS579'),
#  ('subject codes/19EC406 (2).jpg', '19EC406'),
#  ('subject codes/19EC406 (3).jpg', '19EC406'),
#  ('subject codes/19EC406 (4).jpg', '19EC406'),
#  ('subject codes/19EC406 (5).jpg', '19EC406'),
#  ('subject codes/19EC409.jpg', '19EC409'),
#  ('subject codes/19EC410 (2).jpg', '19EC410'),
#  ('subject codes/19EE305 (5).jpg', '19EE305'),
#  ('subject codes/19EE305 (6).jpg', '19EE305'),
#  ('subject codes/19EE309 (3).jpg', '19EE309'),
#  ('subject codes/19EE309 (4).jpg', '19EE309'),
#  ('subject codes/19EE309 (5).jpg', '19EE309'),
#  ('subject codes/19EE309 (6).jpg', '19EE309'),
#  ('subject codes/19EE309 (7).jpg', '19EE309'),
#  ('subject codes/19EE309 (8).jpg', '19EE309'),
#  ('subject codes/19EE309 (10).jpg', '19EE309'),
#  ('subject codes/19EE309 (9).jpg', '19EE309'),
#  ('subject codes/19EE309 (11).jpg', '19EE309'),
#  ('subject codes/19EE404 (25).jpg', '19EE404'),
#  ('subject codes/19EE404 (26).jpg', '19EE404'),
#  ('subject codes/19EE404 (27).jpg', '19EE404'),
#  ('subject codes/19EE404 (28).jpg', '19EE404'),
#  ('subject codes/19MA22O.jpg', '19MA22O'),
#  ('subject codes/19MA508.jpg', '19MA508'),
#  ('subject codes/19MS154 (5).jpg', '19MS154'),
#  ('subject codes/19MS155 (8).jpg', '19MS155'),
#  ('subject codes/19MS155 (9).jpg', '19MS155'),
#  ('subject codes/19MS156 (11).jpg', '19MS156'),
#  ('subject codes/19AI141.jpg', '19AI141'),
#  ('subject codes/19AI142.jpg', '19AI142'),
#  ('subject codes/19AI144.jpg', '19AI144'),
#  ('subject codes/19AI215C.jpg', '19AI215'),
#  ('subject codes/19AI303 (13).jpg', '19AI303'),
#  ('subject codes/19AI303 (14).jpg', '19AI303'),
#  ('subject codes/19AI303 (15).jpg', '19AI303'),
#  ('subject codes/19AI303 (16).jpg', '19AI303'),
#  ('subject codes/19AI303 (17).jpg', '19AI303'),
#  ('subject codes/19AI303 (18).jpg', '19AI303'),
#  ('subject codes/19AI303 (19).jpg', '19AI303'),
#  ('subject codes/19AI303 (20).jpg', '19AI303'),
#  ('subject codes/19AI303 (21).jpg', '19AI303'),
#  ('subject codes/19AI303 (22).jpg', '19AI303'),
#  ('subject codes/19AI303 (23).jpg', '19AI303'),
#  ('subject codes/19AI401 (2).jpg', '19AI401'),
#  ('subject codes/19AI403 (27).jpg', '19AI403'),
#  ('subject codes/19AI403 (28).jpg', '19AI403'),
#  ('subject codes/19AI403 (29).jpg', '19AI403'),
#  ('subject codes/19AI403 (30).jpg', '19AI403'),
#  ('subject codes/19AI403 (31).jpg', '19AI403'),
#  ('subject codes/19AI403 (32).jpg', '19AI403'),
#  ('subject codes/19AI403 (33).jpg', '19AI403'),
#  ('subject codes/19AI403 (34).jpg', '19AI403'),
#  ('subject codes/19AI403 (35).jpg', '19AI403'),
#  ('subject codes/19AI404.jpg', '19AI404'),
#  ('subject codes/19AI405 (6).jpg', '19AI405'),
#  ('subject codes/19AI405 (7).jpg', '19AI405'),
#  ('subject codes/19AI405 (8).jpg', '19AI405'),
#  ('subject codes/19AI405 (9).jpg', '19AI405'),
#  ('subject codes/19AI405 (10).jpg', '19AI405'),
#  ('subject codes/19AI405 (11).jpg', '19AI405'),
#  ('subject codes/19AI405 (12).jpg', '19AI405'),
#  ('subject codes/19AI405 (13).jpg', '19AI405'),
#  ('subject codes/19AI406 (3).jpg', '19AI406'),
#  ('subject codes/19AI406 (4).jpg', '19AI406'),
#  ('subject codes/19AI406 (5).jpg', '19AI406'),
#  ('subject codes/19AI406 (6).jpg', '19AI406'),
#  ('subject codes/19AI406 (7).jpg', '19AI406'),
#  ('subject codes/19AI407 (8).jpg', '19AI407'),
#  ('subject codes/19AI407 (9).jpg', '19AI407'),
#  ('subject codes/19AI407 (10).jpg', '19AI407'),
#  ('subject codes/19AI409 (8).jpg', '19AI409'),
#  ('subject codes/19AI409 (9).jpg', '19AI409'),
#  ('subject codes/19AI410 (29).jpg', '19AI410'),
#  ('subject codes/19AI410 (30).jpg', '19AI410'),
#  ('subject codes/19AI410 (31).jpg', '19AI410'),
#  ('subject codes/19AI410 (32).jpg', '19AI410'),
#  ('subject codes/19AI410 (33).jpg', '19AI410'),
#  ('subject codes/19AI410 (34).jpg', '19AI410'),
#  ('subject codes/19AI410 (35).jpg', '19AI410'),
#  ('subject codes/19AI410 (36).jpg', '19AI410'),
#  ('subject codes/19AI410 (37).jpg', '19AI410'),
#  ('subject codes/19AI410 (38).jpg', '19AI410'),
#  ('subject codes/19AI410 (39).jpg', '19AI410'),
#  ('subject codes/19AI410 (40).jpg', '19AI410'),
#  ('subject codes/19AI410 (41).jpg', '19AI410'),
#  ('subject codes/19AI410 (42).jpg', '19AI410'),
#  ('subject codes/19AI410 (43).jpg', '19AI410'),
#  ('subject codes/19AI410 (44).jpg', '19AI410'),
#  ('subject codes/19AI410 (45).jpg', '19AI410'),
#  ('subject codes/19AI410 (46).jpg', '19AI410'),
#  ('subject codes/19AI411 (3).jpg', '19AI411'),
#  ('subject codes/19AI411 (4).jpg', '19AI411'),
#  ('subject codes/19AI411 (5).jpg', '19AI411'),
#  ('subject codes/19AI411 (6).jpg', '19AI411'),
#  ('subject codes/19AI412 (6).jpg', '19AI412'),
#  ('subject codes/19AI412 (7).jpg', '19AI412'),
#  ('subject codes/19AI413 (5).jpg', '19AI413'),
#  ('subject codes/19AI413 (6).jpg', '19AI413'),
#  ('subject codes/19AI414 (17).jpg', '19AI414'),
#  ('subject codes/19AI414 (18).jpg', '19AI414'),
#  ('subject codes/19AI414 (19).jpg', '19AI414'),
#  ('subject codes/19AI414 (20).jpg', '19AI414'),
#  ('subject codes/19AI414 (21).jpg', '19AI414'),
#  ('subject codes/19AI414 (22).jpg', '19AI414'),
#  ('subject codes/19AI414 (23).jpg', '19AI414'),
#  ('subject codes/19AI414 (24).jpg', '19AI414'),
#  ('subject codes/19AI414 (25).jpg', '19AI414'),
#  ('subject codes/19AI414 (26).jpg', '19AI414'),
#  ('subject codes/19AI414 (27).jpg', '19AI414'),
#  ('subject codes/19AI414 (28).jpg', '19AI414'),
#  ('subject codes/19AI414 (29).jpg', '19AI414'),
#  ('subject codes/19AI414 (30).jpg', '19AI414'),
#  ('subject codes/19AI414 (31).jpg', '19AI414'),
#  ('subject codes/19AI414 (32).jpg', '19AI414'),
#  ('subject codes/19AI414 (33).jpg', '19AI414'),
#  ('subject codes/19AI414 (34).jpg', '19AI414'),
#  ('subject codes/19AI414 (35).jpg', '19AI414'),
#  ('subject codes/19AI414 (36).jpg', '19AI414'),
#  ('subject codes/19AI414 (37).jpg', '19AI414'),
#  ('subject codes/19AI414 (38).jpg', '19AI414'),
#  ('subject codes/19AI414 (39).jpg', '19AI414'),
#  ('subject codes/19AI509.jpg', '19AI509'),
#  ('subject codes/19AI512 (10).jpg', '19AI512'),
#  ('subject codes/19AI512 (11).jpg', '19AI512'),
#  ('subject codes/19AI512 (12).jpg', '19AI512'),
#  ('subject codes/19AI512C (15).jpg', '19AI512'),
#  ('subject codes/19AI513 (8).jpg', '19AI513'),
#  ('subject codes/19AI514C.jpg', '19AI514'),
#  ('subject codes/19AI516.jpg', '19AI516'),
#  ('subject codes/19AI541 (14).jpg', '19AI541'),
#  ('subject codes/19AI546 (6).jpg', '19AI546'),
#  ('subject codes/19AI546 (7).jpg', '19AI546'),
#  ('subject codes/19AI547 (7).jpg', '19AI547'),
#  ('subject codes/19AI547 (8).jpg', '19AI547'),
#  ('subject codes/19AI550 (9).jpg', '19AI550'),
#  ('subject codes/19AI550 (10).jpg', '19AI550'),
#  ('subject codes/19AM401.jpg', '19AM401'),
#  ('subject codes/19AM401 (2).jpg', '19AM401'),
#  ('subject codes/19AM401 (3).jpg', '19AM401'),
#  ('subject codes/19AM401 (4).jpg', '19AM401'),
#  ('subject codes/19AM508 (4).jpg', '19AM508'),
#  ('subject codes/19CS304.jpg', '19CS304'),
#  ('subject codes/19CS305 (16).jpg', '19CS305'),
#  ('subject codes/19CS305 (17).jpg', '19CS305'),
#  ('subject codes/19CS305 (18).jpg', '19CS305'),
#  ('subject codes/19CS305 (19).jpg', '19CS305'),
#  ('subject codes/19CS305 (20).jpg', '19CS305'),
#  ('subject codes/19CS305 (21).jpg', '19CS305'),
#  ('subject codes/19CS404 (29).jpg', '19CS404'),
#  ('subject codes/19CS404 (30).jpg', '19CS404'),
#  ('subject codes/19CS404 (31).jpg', '19CS404'),
#  ('subject codes/19CS404 (32).jpg', '19CS404'),
#  ('subject codes/19CS404 (33).jpg', '19CS404'),
#  ('subject codes/19CS404 (34).jpg', '19CS404'),
#  ('subject codes/19CS404 (35).jpg', '19CS404'),
#  ('subject codes/19CS404 (36).jpg', '19CS404'),
#  ('subject codes/19CS404 (37).jpg', '19CS404'),
#  ('subject codes/19CS404 (38).jpg', '19CS404'),
#  ('subject codes/19CS404 (39).jpg', '19CS404'),
#  ('subject codes/19CS404 (40).jpg', '19CS404'),
#  ('subject codes/19CS405 (15).jpg', '19CS405'),
#  ('subject codes/19CS405 (16).jpg', '19CS405'),
#  ('subject codes/19CS405 (17).jpg', '19CS405'),
#  ('subject codes/19CS405 (18).jpg', '19CS405'),
#  ('subject codes/19CS405 (19).jpg', '19CS405'),
#  ('subject codes/19CS405 (20).jpg', '19CS405'),
#  ('subject codes/19CS405 (21).jpg', '19CS405'),
#  ('subject codes/19CS405 (22).jpg', '19CS405'),
#  ('subject codes/19CS405 (23).jpg', '19CS405'),
#  ('subject codes/19CS405 (24).jpg', '19CS405'),
#  ('subject codes/19CS405 (25).jpg', '19CS405'),
#  ('subject codes/19CS405 (26).jpg', '19CS405'),
#  ('subject codes/19CS405 (27).jpg', '19CS405'),
#  ('subject codes/19CS405 (28).jpg', '19CS405'),
#  ('subject codes/19CS405 (29).jpg', '19CS405'),
#  ('subject codes/19CS405 (30).jpg', '19CS405'),
#  ('subject codes/19CS405 (31).jpg', '19CS405'),
#  ('subject codes/19CS405 (32).jpg', '19CS405'),
#  ('subject codes/19CS405 (33).jpg', '19CS405'),
#  ('subject codes/19CS405 (34).jpg', '19CS405'),
#  ('subject codes/19CS405 (35).jpg', '19CS405'),
#  ('subject codes/19CS405 (36).jpg', '19CS405'),
#  ('subject codes/19CS406 (23).jpg', '19CS406'),
#  ('subject codes/19CS406 (24).jpg', '19CS406'),
#  ('subject codes/19CS406 (25).jpg', '19CS406'),
#  ('subject codes/19CS406 (26).jpg', '19CS406'),
#  ('subject codes/19CS406 (27).jpg', '19CS406'),
#  ('subject codes/19CS406 (28).jpg', '19CS406'),
#  ('subject codes/19CS406 (29).jpg', '19CS406'),
#  ('subject codes/19CS406 (30).jpg', '19CS406'),
#  ('subject codes/19CS406 (31).jpg', '19CS406'),
#  ('subject codes/19CS406 (32).jpg', '19CS406'),
#  ('subject codes/19CS406 (33).jpg', '19CS406'),
#  ('subject codes/19CS407 (19).jpg', '19CS407'),
#  ('subject codes/19CS407 (20).jpg', '19CS407'),
#  ('subject codes/19CS407 (21).jpg', '19CS407'),
#  ('subject codes/19CS407 (22).jpg', '19CS407'),
#  ('subject codes/19CS407 (23).jpg', '19CS407'),
#  ('subject codes/19CS407 (24).jpg', '19CS407'),
#  ('subject codes/19CS408 (12).jpg', '19CS408'),
#  ('subject codes/19CS408 (20).jpg', '19CS408'),
#  ('subject codes/19CS408 (21).jpg', '19CS408'),
#  ('subject codes/19CS408 (22).jpg', '19CS408'),
#  ('subject codes/19CS408 (23).jpg', '19CS408'),
#  ('subject codes/19CS408 (24).jpg', '19CS408'),
#  ('subject codes/19CS408 (25).jpg', '19CS408'),
#  ('subject codes/19CS408 (26).jpg', '19CS408'),
#  ('subject codes/19CS409 (28).jpg', '19CS409'),
#  ('subject codes/19CS409 (29).jpg', '19CS409'),
#  ('subject codes/19CS409 (30).jpg', '19CS409'),
#  ('subject codes/19CS409 (31).jpg', '19CS409'),
#  ('subject codes/19CS409 (32).jpg', '19CS409'),
#  ('subject codes/19CS411 (5).jpg', '19CS411'),
#  ('subject codes/19CS415 (22).jpg', '19CS415'),
#  ('subject codes/19CS415 (23).jpg', '19CS415'),
#  ('subject codes/19CS415 (24).jpg', '19CS415'),
#  ('subject codes/19CS416 (2).jpg', '19CS416'),
#  ('subject codes/19CS416 (3).jpg', '19CS416'),
#  ('subject codes/19CS417 (10).jpg', '19CS417'),
#  ('subject codes/19CS417 (11).jpg', '19CS417'),
#  ('subject codes/19CS417 (12).jpg', '19CS417'),
#  ('subject codes/19CS418 (8).jpg', '19CS418'),
#  ('subject codes/19CS418 (9).jpg', '19CS418'),
#  ('subject codes/19CS419 (2).jpg', '19CS419'),
#  ('subject codes/19CS420 (8).jpg', '19CS420'),
#  ('subject codes/19CS504 (12).jpg', '19CS504'),
#  ('subject codes/19CS504 (13).jpg', '19CS504'),
#  ('subject codes/19CS519.jpg', '19CS519'),
#  ('subject codes/19CS549.jpg', '19CS549'),
#  ('subject codes/19CS549 (2).jpg', '19CS549'),
#  ('subject codes/19CS565 (2).jpg', '19CS565'),
#  ('subject codes/19CS579 (3).jpg', '19CS579'),
#  ('subject codes/19CS579 (4).jpg', '19CS579'),
#  ('subject codes/19CS579 (5).jpg', '19CS579'),
#  ('subject codes/19CS579 (6).jpg', '19CS579'),
#  ('subject codes/19EE205.jpg', '19EE205'),
#  ('subject codes/19EE305 (7).jpg', '19EE305'),
#  ('subject codes/19EE305 (8).jpg', '19EE305'),
#  ('subject codes/19EE305 (9).jpg', '19EE305'),
#  ('subject codes/19EE305 (10).jpg', '19EE305'),
#  ('subject codes/19EE305 (11).jpg', '19EE305'),
#  ('subject codes/19EE305 (12).jpg', '19EE305'),
#  ('subject codes/19EE305 (13).jpg', '19EE305'),
#  ('subject codes/19EE305 (14).jpg', '19EE305'),
#  ('subject codes/19EE305 (15).jpg', '19EE305'),
#  ('subject codes/19EE305 (16).jpg', '19EE305'),
#  ('subject codes/19EE305 (17).jpg', '19EE305'),
#  ('subject codes/19EE305 (18).jpg', '19EE305'),
#  ('subject codes/19EE305 (19).jpg', '19EE305'),
#  ('subject codes/19EE305 (20).jpg', '19EE305'),
#  ('subject codes/19EE305 (21).jpg', '19EE305'),
#  ('subject codes/19EE305 (22).jpg', '19EE305'),
#  ('subject codes/19EE309 (12).jpg', '19EE309'),
#  ('subject codes/19EE309 (13).jpg', '19EE309'),
#  ('subject codes/19EE309 (14).jpg', '19EE309'),
#  ('subject codes/19EE309 (15).jpg', '19EE309'),
#  ('subject codes/19EE309 (16).jpg', '19EE309'),
#  ('subject codes/19EE309 (17).jpg', '19EE309'),
#  ('subject codes/19EE309 (18).jpg', '19EE309'),
#  ('subject codes/19EE309 (19).jpg', '19EE309'),
#  ('subject codes/19EE404 (29).jpg', '19EE404'),
#  ('subject codes/19EE404 (30).jpg', '19EE404'),
#  ('subject codes/19EE404 (31).jpg', '19EE404'),
#  ('subject codes/19EE404 (32).jpg', '19EE404'),
#  ('subject codes/19EE404 (33).jpg', '19EE404'),
#  ('subject codes/19MA220 (13).jpg', '19MA220'),
#  ('subject codes/19MA220 (14).jpg', '19MA220'),
#  ('subject codes/19MS150.jpg', '19MS150'),
#  ('subject codes/19MS154 (6).jpg', '19MS154'),
#  ('subject codes/19MS155 (10).jpg', '19MS155'),
#  ('subject codes/19MS155 (11).jpg', '19MS155'),
#  ('subject codes/19MS156 (12).jpg', '19MS156'),
#  ('subject codes/19MS156 (13).jpg', '19MS156'),
#  ('subject codes/19MS156 (14).jpg', '19MS156'),
#  ('subject codes/19MS156 (15).jpg', '19MS156'),
#  ('subject codes/19AI403 (36).jpg', '19AI403'),
#  ('subject codes/19AI403 (37).jpg', '19AI403'),
#  ('subject codes/19AI403 (38).jpg', '19AI403'),
#  ('subject codes/19AI405 (14).jpg', '19AI405'),
#  ('subject codes/19AI405 (15).jpg', '19AI405'),
#  ('subject codes/19AI405 (16).jpg', '19AI405'),
#  ('subject codes/19AI405 (17).jpg', '19AI405'),
#  ('subject codes/19AI406 (8).jpg', '19AI406'),
#  ('subject codes/19AI407 (11).jpg', '19AI407'),
#  ('subject codes/19AI407 (12).jpg', '19AI407'),
#  ('subject codes/19AI407 (13).jpg', '19AI407'),
#  ('subject codes/19AI409 (10).jpg', '19AI409'),
#  ('subject codes/19AI409 (11).jpg', '19AI409'),
#  ('subject codes/19AI409 (12).jpg', '19AI409'),
#  ('subject codes/19AI409 (13).jpg', '19AI409'),
#  ('subject codes/19AI409 (14).jpg', '19AI409'),
#  ('subject codes/19AI409 (15).jpg', '19AI409'),
#  ('subject codes/19AI409 (16).jpg', '19AI409'),
#  ('subject codes/19AI409 (17).jpg', '19AI409'),
#  ('subject codes/19AI410 (47).jpg', '19AI410'),
#  ('subject codes/19AI410 (48).jpg', '19AI410'),
#  ('subject codes/19AI410 (49).jpg', '19AI410'),
#  ('subject codes/19AI410 (50).jpg', '19AI410'),
#  ('subject codes/19AI410 (51).jpg', '19AI410'),
#  ('subject codes/19AI411 (7).jpg', '19AI411'),
#  ('subject codes/19AI411 (8).jpg', '19AI411'),
#  ('subject codes/19AI411 (9).jpg', '19AI411'),
#  ('subject codes/19AI411 (10).jpg', '19AI411'),
#  ('subject codes/19AI411 (11).jpg', '19AI411'),
#  ('subject codes/19AI411 (12).jpg', '19AI411'),
#  ('subject codes/19AI411 (13).jpg', '19AI411'),
#  ('subject codes/19AI411 (14).jpg', '19AI411'),
#  ('subject codes/19AI412 (8).jpg', '19AI412'),
#  ('subject codes/19AI412 (9).jpg', '19AI412'),
#  ('subject codes/19AI412 (10).jpg', '19AI412'),
#  ('subject codes/19AI412 (11).jpg', '19AI412'),
#  ('subject codes/19AI412 (12).jpg', '19AI412'),
#  ('subject codes/19AI412 (13).jpg', '19AI412'),
#  ('subject codes/19AI412 (14).jpg', '19AI412'),
#  ('subject codes/19AI412 (15).jpg', '19AI412'),
#  ('subject codes/19AI412 (16).jpg', '19AI412'),
#  ('subject codes/19AI412 (17).jpg', '19AI412'),
#  ('subject codes/19AI412 (18).jpg', '19AI412'),
#  ('subject codes/19AI412 (19).jpg', '19AI412'),
#  ('subject codes/19AI412 (20).jpg', '19AI412'),
#  ('subject codes/19AI413 (7).jpg', '19AI413'),
#  ('subject codes/19AI413 (8).jpg', '19AI413'),
#  ('subject codes/19AI413 (9).jpg', '19AI413'),
#  ('subject codes/19AI413 (10).jpg', '19AI413'),
#  ('subject codes/19AI413 (11).jpg', '19AI413'),
#  ('subject codes/19AI413 (12).jpg', '19AI413'),
#  ('subject codes/19AI413 (13).jpg', '19AI413'),
#  ('subject codes/19AI413 (14).jpg', '19AI413'),
#  ('subject codes/19AI413 (15).jpg', '19AI413'),
#  ('subject codes/19AI414 (41).jpg', '19AI414'),
#  ('subject codes/19AI414 (42).jpg', '19AI414'),
#  ('subject codes/19AI419.jpg', '19AI419'),
#  ('subject codes/19AI502.jpg', '19AI502'),
#  ('subject codes/19AI502 (2).jpg', '19AI502'),
#  ('subject codes/19AI502 (3).jpg', '19AI502'),
#  ('subject codes/19AI502 (4).jpg', '19AI502'),
#  ('subject codes/19AI502 (5).jpg', '19AI502'),
#  ('subject codes/19AI502 (6).jpg', '19AI502'),
#  ('subject codes/19AI505.jpg', '19AI505'),
#  ('subject codes/19AI512 (13).jpg', '19AI512'),
#  ('subject codes/19AI512 (14).jpg', '19AI512'),
#  ('subject codes/19AI512 (15).jpg', '19AI512'),
#  ('subject codes/19AI512 (16).jpg', '19AI512'),
#  ('subject codes/19AI512 (17).jpg', '19AI512'),
#  ('subject codes/19AI512 (18).jpg', '19AI512'),
#  ('subject codes/19AI512 (19).jpg', '19AI512'),
#  ('subject codes/19AI512C(20).jpg', '19AI512'),
#  ('subject codes/19AI513 (9).jpg', '19AI513'),
#  ('subject codes/19AI513 (10).jpg', '19AI513'),
#  ('subject codes/19AI521 (2).jpg', '19AI521'),
#  ('subject codes/19AI541 (15).jpg', '19AI541'),
#  ('subject codes/19AI547 (9).jpg', '19AI547'),
#  ('subject codes/19AI550 (11).jpg', '19AI550'),
#  ('subject codes/19AI550 (12).jpg', '19AI550'),
#  ('subject codes/19AI550 (13).jpg', '19AI550'),
#  ('subject codes/19AM401 (5).jpg', '19AM401'),
#  ('subject codes/19AM401 (6).jpg', '19AM401'),
#  ('subject codes/19AM401 (7).jpg', '19AM401'),
#  ('subject codes/19AM508 (5).jpg', '19AM508'),
#  ('subject codes/19AM508 (6).jpg', '19AM508'),
#  ('subject codes/19CS305 (22).jpg', '19CS305'),
#  ('subject codes/19CS403.jpg', '19CS403'),
#  ('subject codes/19CS404 (41).jpg', '19CS404'),
#  ('subject codes/19CS404 (42).jpg', '19CS404'),
#  ('subject codes/19CS404 (43).jpg', '19CS404'),
#  ('subject codes/19CS404 (44).jpg', '19CS404'),
#  ('subject codes/19CS404 (45).jpg', '19CS404'),
#  ('subject codes/19CS404 (46).jpg', '19CS404'),
#  ('subject codes/19CS404 (47).jpg', '19CS404'),
#  ('subject codes/19CS404 (48).jpg', '19CS404'),
#  ('subject codes/19CS404 (49).jpg', '19CS404'),
#  ('subject codes/19CS405 (37).jpg', '19CS405'),
#  ('subject codes/19CS405 (38).jpg', '19CS405'),
#  ('subject codes/19CS405 (39).jpg', '19CS405'),
#  ('subject codes/19CS405 (40).jpg', '19CS405'),
#  ('subject codes/19CS405 (41).jpg', '19CS405'),
#  ('subject codes/19CS405 (42).jpg', '19CS405'),
#  ('subject codes/19CS406 (34).jpg', '19CS406'),
#  ('subject codes/19CS406 (35).jpg', '19CS406'),
#  ('subject codes/19CS406 (36).jpg', '19CS406'),
#  ('subject codes/19CS406 (37).jpg', '19CS406'),
#  ('subject codes/19CS407 (25).jpg', '19CS407'),
#  ('subject codes/19CS407 (26).jpg', '19CS407'),
#  ('subject codes/19CS407 (27).jpg', '19CS407'),
#  ('subject codes/19CS407 (28).jpg', '19CS407'),
#  ('subject codes/19CS407 (29).jpg', '19CS407'),
#  ('subject codes/19CS408 (27).jpg', '19CS408'),
#  ('subject codes/19CS408 (28).jpg', '19CS408'),
#  ('subject codes/19CS409 (33).jpg', '19CS409'),
#  ('subject codes/19CS409 (34).jpg', '19CS409'),
#  ('subject codes/19CS409 (35).jpg', '19CS409'),
#  ('subject codes/19CS409 (36).jpg', '19CS409'),
#  ('subject codes/19CS409 (37).jpg', '19CS409'),
#  ('subject codes/19CS409 (38).jpg', '19CS409'),
#  ('subject codes/19CS409 (39).jpg', '19CS409'),
#  ('subject codes/19CS409 (40).jpg', '19CS409'),
#  ('subject codes/19CS409 (41).jpg', '19CS409'),
#  ('subject codes/19CS409 (42).jpg', '19CS409'),
#  ('subject codes/19CS409 (43).jpg', '19CS409'),
#  ('subject codes/19CS413.jpg', '19CS413'),
#  ('subject codes/19CS413 (15).jpg', '19CS413'),
#  ('subject codes/19CS414 (18).jpg', '19CS414'),
#  ('subject codes/19CS415 (25).jpg', '19CS415'),
#  ('subject codes/19CS415 (26).jpg', '19CS415'),
#  ('subject codes/19CS417 (13).jpg', '19CS417'),
#  ('subject codes/19CS417 (14).jpg', '19CS417'),
#  ('subject codes/19CS418 (10).jpg', '19CS418'),
#  ('subject codes/19CS419 (3).jpg', '19CS419'),
#  ('subject codes/19CS504 (14).jpg', '19CS504'),
#  ('subject codes/19CS504 (15).jpg', '19CS504'),
#  ('subject codes/19CS504 (16).jpg', '19CS504'),
#  ('subject codes/19CS569.jpg', '19CS569'),
#  ('subject codes/19CS570 (5).jpg', '19CS570'),
#  ('subject codes/19CS570 (6).jpg', '19CS570'),
#  ('subject codes/19CS570 (7).jpg', '19CS570'),
#  ('subject codes/19EE305 (23).jpg', '19EE305'),
#  ('subject codes/19EE305 (24).jpg', '19EE305'),
#  ('subject codes/19EE309 (20).jpg', '19EE309'),
#  ('subject codes/19EE309 (21).jpg', '19EE309'),
#  ('subject codes/19EE309 (22).jpg', '19EE309'),
#  ('subject codes/19EE309 (23).jpg', '19EE309'),
#  ('subject codes/19EE309 (24).jpg', '19EE309'),
#  ('subject codes/19EE309 (25).jpg', '19EE309'),
#  ('subject codes/19EE309 (26).jpg', '19EE309'),
#  ('subject codes/19EE309 (27).jpg', '19EE309'),
#  ('subject codes/19EE309 (28).jpg', '19EE309'),
#  ('subject codes/19EE404 (34).jpg', '19EE404'),
#  ('subject codes/19EE404 (35).jpg', '19EE404'),
#  ('subject codes/19IT402.jpg', '19IT402'),
#  ('subject codes/19IT402 (2).jpg', '19IT402'),
#  ('subject codes/19IT402 (3).jpg', '19IT402'),
#  ('subject codes/19MA154.jpg', '19MA154'),
#  ('subject codes/19MS154 (7).jpg', '19MS154'),
#  ('subject codes/19MS154 (8).jpg', '19MS154'),
#  ('subject codes/19MS154 (9).jpg', '19MS154'),
#  ('subject codes/19MS154 (10).jpg', '19MS154'),
#  ('subject codes/19MS154 (11).jpg', '19MS154'),
#  ('subject codes/19MS154 (12).jpg', '19MS154'),
#  ('subject codes/19MS154 (13).jpg', '19MS154'),
#  ('subject codes/19MS154 (14).jpg', '19MS154'),
#  ('subject codes/19MS155 (12).jpg', '19MS155'),
#  ('subject codes/19MS155 (13).jpg', '19MS155'),
#  ('subject codes/19MS156 (16).jpg', '19MS156'),
#  ('subject codes/19MS156 (17).jpg', '19MS156'),
#  ('subject codes/19MS176.jpg', '19MS176'),
#  ('subject codes/19AI303 (24).jpg', '19AI303'),
#  ('subject codes/19AI303 (25).jpg', '19AI303'),
#  ('subject codes/19AI303 (26).jpg', '19AI303'),
#  ('subject codes/19AI303 (27).jpg', '19AI303'),
#  ('subject codes/19AI403 (39).jpg', '19AI403'),
#  ('subject codes/19AI403 (40).jpg', '19AI403'),
#  ('subject codes/19AI403 (41).jpg', '19AI403'),
#  ('subject codes/19AI403 (42).jpg', '19AI403'),
#  ('subject codes/19AI403 (43).jpg', '19AI403'),
#  ('subject codes/19AI403 (44).jpg', '19AI403'),
#  ('subject codes/19AI403 (45).jpg', '19AI403'),
#  ('subject codes/19AI403 (46).jpg', '19AI403'),
#  ('subject codes/19AI403 (47).jpg', '19AI403'),
#  ('subject codes/19AI404 (2).jpg', '19AI404'),
#  ('subject codes/19AI405 (18).jpg', '19AI405'),
#  ('subject codes/19AI405 (19).jpg', '19AI405'),
#  ('subject codes/19AI405 (20).jpg', '19AI405'),
#  ('subject codes/19AI405 (21).jpg', '19AI405'),
#  ('subject codes/19AI405 (22).jpg', '19AI405'),
#  ('subject codes/19AI406 (9).jpg', '19AI406'),
#  ('subject codes/19AI406 (10).jpg', '19AI406'),
#  ('subject codes/19AI406 (11).jpg', '19AI406'),
#  ('subject codes/19AI406 (12).jpg', '19AI406'),
#  ('subject codes/19AI406 (13).jpg', '19AI406'),
#  ('subject codes/19AI406 (14).jpg', '19AI406'),
#  ('subject codes/19AI406 (15).jpg', '19AI406'),
#  ('subject codes/19AI406 (16).jpg', '19AI406'),
#  ('subject codes/19AI406 (17).jpg', '19AI406'),
#  ('subject codes/19AI407 (14).jpg', '19AI407'),
#  ...]

# %%
# Split the data
random.shuffle(cleaned_pairs)
total = len(cleaned_pairs)
train = cleaned_pairs[:int(0.8 * total)]
val = cleaned_pairs[int(0.8 * total):int(0.9 * total)]
test = cleaned_pairs[int(0.9 * total):]
print(f"Train: {len(train)}, Val: {len(val)}, Test: {len(test)}")

class SubjectCodeDataset(Dataset):
    def __init__(self, image_paths, labels, transform=None):
        self.image_paths = image_paths
        self.labels = labels
        self.transform = transform

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        image = Image.open(self.image_paths[idx]).convert('L')
        label = self.labels[idx]
        if self.transform:
            image = self.transform(image)
        label_seq = [int(c) + 1 if c.isdigit() else ord(c) - ord('A') + 11 for c in label]
        return image, torch.tensor(label_seq, dtype=torch.long)
# Out:
# Train: 886, Val: 111, Test: 111

# %%
# Custom transform for random brightness
class RandomBrightness(object):
    def __init__(self, delta=0.3):
        self.delta = delta

    def __call__(self, img):
        brightness = random.uniform(-self.delta, self.delta)
        img = torch.tensor(np.array(img)).float() / 255.0  # Convert to tensor [0,1]
        img = img + brightness
        img = torch.clamp(img, 0, 1)  # Keep values between 0 and 1
        return Image.fromarray((img.numpy() * 255).astype(np.uint8))

# Training transform with augmentation
train_transform = transforms.Compose([
    transforms.RandomRotation(15),
    transforms.RandomAffine(degrees=0, translate=(0.1, 0.1), scale=(0.8, 1.2)),
    RandomBrightness(0.3),
    transforms.GaussianBlur(kernel_size=3),
    transforms.Resize((32, 128)),  # Adjusted for smaller subject code images
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,)),
    transforms.Lambda(lambda x: x + 0.05 * torch.randn_like(x)),
    transforms.Lambda(lambda x: torch.clamp(x, -1, 1)),
])

# Validation/test transform (no augmentation)
val_test_transform = transforms.Compose([
    transforms.Resize((32, 128)),  # Adjusted for smaller subject code images
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))
])

# Create datasets
train_dataset = SubjectCodeDataset([p for p, _ in train], [l for _, l in train], transform=train_transform)
val_dataset = SubjectCodeDataset([p for p, _ in val], [l for _, l in val], transform=val_test_transform)
test_dataset = SubjectCodeDataset([p for p, _ in test], [l for _, l in test], transform=val_test_transform)

# Data loaders
batch_size = 32
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
# Define the CRNN model
class CRNN(nn.Module):
    def __init__(self, num_classes):
        super(CRNN, self).__init__()
        self.cnn = nn.Sequential(
            nn.Conv2d(1, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),  # (N, 64, 16, W/2)
            nn.Conv2d(64, 128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),  # (N, 128, 8, W/4)
            nn.Dropout2d(0.3),
            nn.Conv2d(128, 256, kernel_size=3, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.Conv2d(256, 256, kernel_size=3, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.MaxPool2d((2,1), (2,1)),  # (N, 256, 4, W/4)
            nn.Conv2d(256, 512, kernel_size=3, padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(),
            nn.Conv2d(512, 512, kernel_size=3, padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(),
            nn.MaxPool2d((2,1), (2,1)),  # (N, 512, 2, W/4)
            nn.Dropout2d(0.3),
            nn.Conv2d(512, 512, kernel_size=(2,1)),  # (N, 512, 1, W/4)
            nn.BatchNorm2d(512),
            nn.ReLU(),
        )
        self.rnn = nn.LSTM(512, 256, num_layers=2, bidirectional=True, dropout=0.3)
        self.dropout = nn.Dropout(0.5)
        self.fc = nn.Linear(512, num_classes)  # 512 because bidirectional (256 * 2)

    def forward(self, x):
        x = self.cnn(x)  # (N, 512, 1, W/4)
        x = x.squeeze(2)  # (N, 512, W/4)
        x = x.permute(2, 0, 1)  # (W/4, N, 512) for LSTM
        x, _ = self.rnn(x)  # (W/4, N, 512)
        x = self.dropout(x)
        x = self.fc(x)  # (W/4, N, num_classes)
        return x

# Initialize the model for 37 classes (blank + 0-9 + A-Z)
model = CRNN(num_classes=37)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)

# Define loss function and optimizer
criterion = nn.CTCLoss(blank=0)
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
model
# Out:
# CRNN(
#   (cnn): Sequential(
#     (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): Dropout2d(p=0.3, inplace=False)
#     (9): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (10): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (11): ReLU()
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (14): ReLU()
#     (15): MaxPool2d(kernel_size=(2, 1), stride=(2, 1), padding=0, dilation=1, ceil_mode=False)
#     (16): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (17): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (18): ReLU()
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (21): ReLU()
#     (22): MaxPool2d(kernel_size=(2, 1), stride=(2, 1), padding=0, dilation=1, ceil_mode=False)
#     (23): Dropout2d(p=0.3, inplace=False)
#     (24): Conv2d(512, 512, kernel_size=(2, 1), stride=(1, 1))
#     (25): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (26): ReLU()
#   )
#   (rnn): LSTM(512, 256, num_layers=2, dropout=0.3, bidirectional=True)
#   (dropout): Dropout(p=0.5, inplace=False)
#   (fc): Linear(in_features=512, out_features=37, bias=True)
# )

# %%
# Character mapping for decoding
char_map = {i: str(i-1) for i in range(1, 11)}  # 1-10 -> '0'-'9'
char_map.update({i: chr(i - 11 + ord('A')) for i in range(11, 37)})  # 11-36 -> 'A'-'Z'

# Decoding function
def decode_predictions(outputs):
    outputs = outputs.softmax(2).argmax(2)  # (T, N)
    batch_size = outputs.size(1)
    decoded = []
    for b in range(batch_size):
        seq = outputs[:, b].cpu().numpy()
        prev = 0
        result = []
        for s in seq:
            if s != 0 and s != prev:
                result.append(char_map.get(s, ''))
            prev = s
        decoded.append(''.join(result))
    return decoded

# %%
# Training loop with validation
num_epochs = 200
for epoch in range(num_epochs):
    # Training phase
    model.train()
    train_loss = 0
    train_correct = 0
    train_total = 0
    for images, targets in train_loader:
        images, targets = images.to(device), targets.to(device)
        optimizer.zero_grad()
        outputs = model(images)  # (W/4, N, num_classes)
        outputs_log = outputs.log_softmax(2)
        batch_size = images.size(0)
        input_lengths = torch.full((batch_size,), outputs.size(0), dtype=torch.long, device=device)
        target_lengths = torch.full((batch_size,), 7, dtype=torch.long, device=device)
        targets_flat = targets.view(-1)
        loss = criterion(outputs_log, targets_flat, input_lengths, target_lengths)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()

        # Compute training accuracy
        predictions = decode_predictions(outputs)
        target_labels = [''.join([char_map[d.item()] for d in t]) for t in targets]
        for pred, target in zip(predictions, target_labels):
            if pred == target:
                train_correct += 1
            train_total += 1

    train_loss = train_loss / len(train_loader)
    train_accuracy = train_correct / train_total * 100

    # Validation phase
    model.eval()
    val_loss = 0
    val_correct = 0
    val_total = 0
    with torch.no_grad():
        for images, targets in val_loader:
            images, targets = images.to(device), targets.to(device)
            outputs = model(images)
            outputs_log = outputs.log_softmax(2)
            batch_size = images.size(0)
            input_lengths = torch.full((batch_size,), outputs.size(0), dtype=torch.long, device=device)
            target_lengths = torch.full((batch_size,), 7, dtype=torch.long, device=device)
            targets_flat = targets.view(-1)
            loss = criterion(outputs_log, targets_flat, input_lengths, target_lengths)
            val_loss += loss.item()

            # Compute validation accuracy
            predictions = decode_predictions(outputs)
            target_labels = [''.join([char_map[d.item()] for d in t]) for t in targets]
            for pred, target in zip(predictions, target_labels):
                if pred == target:
                    val_correct += 1
                val_total += 1

    val_loss = val_loss / len(val_loader)
    val_accuracy = val_correct / val_total * 100

    # Print metrics
    print(f"Epoch {epoch+1}/{num_epochs}, "
          f"Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}, "
          f"Train Acc: {train_accuracy:.2f}%, Val Acc: {val_accuracy:.2f}%")
# Out:
# Epoch 1/200, Train Loss: 1.0675, Val Loss: 1.0457, Train Acc: 1.58%, Val Acc: 3.60%
# Epoch 2/200, Train Loss: 1.0665, Val Loss: 1.0450, Train Acc: 1.92%, Val Acc: 4.50%
# Epoch 3/200, Train Loss: 1.0647, Val Loss: 1.0473, Train Acc: 1.58%, Val Acc: 0.00%
# Epoch 4/200, Train Loss: 1.0666, Val Loss: 1.0468, Train Acc: 1.13%, Val Acc: 3.60%
# Epoch 5/200, Train Loss: 1.0645, Val Loss: 1.0430, Train Acc: 1.58%, Val Acc: 4.50%
# Epoch 6/200, Train Loss: 1.0680, Val Loss: 1.0462, Train Acc: 1.35%, Val Acc: 0.00%
# Epoch 7/200, Train Loss: 1.0642, Val Loss: 1.0509, Train Acc: 1.02%, Val Acc: 0.00%
# Epoch 8/200, Train Loss: 1.0650, Val Loss: 1.0495, Train Acc: 1.69%, Val Acc: 0.00%
# Epoch 9/200, Train Loss: 1.0639, Val Loss: 1.0436, Train Acc: 2.03%, Val Acc: 0.00%
# Epoch 10/200, Train Loss: 1.0615, Val Loss: 1.0465, Train Acc: 1.24%, Val Acc: 0.00%
# Epoch 11/200, Train Loss: 1.0646, Val Loss: 1.0550, Train Acc: 1.69%, Val Acc: 2.70%
# Epoch 12/200, Train Loss: 1.0667, Val Loss: 1.0441, Train Acc: 0.56%, Val Acc: 4.50%
# Epoch 13/200, Train Loss: 1.0626, Val Loss: 1.0477, Train Acc: 1.92%, Val Acc: 0.00%
# Epoch 14/200, Train Loss: 1.0611, Val Loss: 1.0421, Train Acc: 0.68%, Val Acc: 0.00%
# Epoch 15/200, Train Loss: 1.0607, Val Loss: 1.0387, Train Acc: 0.79%, Val Acc: 4.50%
# Epoch 16/200, Train Loss: 1.0637, Val Loss: 1.0440, Train Acc: 1.92%, Val Acc: 0.00%
# Epoch 17/200, Train Loss: 1.0671, Val Loss: 1.0483, Train Acc: 1.24%, Val Acc: 0.00%
# Epoch 18/200, Train Loss: 1.0626, Val Loss: 1.0495, Train Acc: 1.69%, Val Acc: 0.00%
# Epoch 19/200, Train Loss: 1.0592, Val Loss: 1.0434, Train Acc: 1.81%, Val Acc: 3.60%
# Epoch 20/200, Train Loss: 1.0607, Val Loss: 1.0450, Train Acc: 2.03%, Val Acc: 0.00%
# Epoch 21/200, Train Loss: 1.0623, Val Loss: 1.0500, Train Acc: 1.24%, Val Acc: 0.00%
# Epoch 22/200, Train Loss: 1.0622, Val Loss: 1.0502, Train Acc: 1.81%, Val Acc: 2.70%
# Epoch 23/200, Train Loss: 1.0639, Val Loss: 1.0506, Train Acc: 1.92%, Val Acc: 0.00%
# Epoch 24/200, Train Loss: 1.0603, Val Loss: 1.0550, Train Acc: 2.93%, Val Acc: 2.70%
# Epoch 25/200, Train Loss: 1.0647, Val Loss: 1.0454, Train Acc: 0.79%, Val Acc: 0.00%
# Epoch 26/200, Train Loss: 1.0566, Val Loss: 1.0430, Train Acc: 2.03%, Val Acc: 4.50%
# Epoch 27/200, Train Loss: 1.0588, Val Loss: 1.0390, Train Acc: 0.90%, Val Acc: 4.50%
# Epoch 28/200, Train Loss: 1.0608, Val Loss: 1.0421, Train Acc: 2.82%, Val Acc: 0.00%
# Epoch 29/200, Train Loss: 1.0584, Val Loss: 1.0424, Train Acc: 1.58%, Val Acc: 4.50%
# Epoch 30/200, Train Loss: 1.0557, Val Loss: 1.0459, Train Acc: 1.58%, Val Acc: 0.00%
# Epoch 31/200, Train Loss: 1.0572, Val Loss: 1.0463, Train Acc: 1.58%, Val Acc: 0.00%
# Epoch 32/200, Train Loss: 1.0571, Val Loss: 1.0367, Train Acc: 0.68%, Val Acc: 0.00%
# Epoch 33/200, Train Loss: 1.0590, Val Loss: 1.0436, Train Acc: 0.68%, Val Acc: 0.00%
# Epoch 34/200, Train Loss: 1.0588, Val Loss: 1.0461, Train Acc: 1.58%, Val Acc: 0.00%
# Epoch 35/200, Train Loss: 1.0598, Val Loss: 1.0348, Train Acc: 1.58%, Val Acc: 0.00%
# Epoch 36/200, Train Loss: 1.0559, Val Loss: 1.0315, Train Acc: 1.69%, Val Acc: 0.00%
# Epoch 37/200, Train Loss: 1.0658, Val Loss: 1.0477, Train Acc: 1.13%, Val Acc: 0.00%
# Epoch 38/200, Train Loss: 1.0627, Val Loss: 1.0439, Train Acc: 1.81%, Val Acc: 0.00%
# Epoch 39/200, Train Loss: 1.0588, Val Loss: 1.0357, Train Acc: 1.58%, Val Acc: 0.00%
# Epoch 40/200, Train Loss: 1.0579, Val Loss: 1.0279, Train Acc: 0.79%, Val Acc: 0.00%
# Epoch 41/200, Train Loss: 1.0617, Val Loss: 1.0425, Train Acc: 2.03%, Val Acc: 0.00%
# Epoch 42/200, Train Loss: 1.0569, Val Loss: 1.0324, Train Acc: 1.69%, Val Acc: 0.00%
# Epoch 43/200, Train Loss: 1.0524, Val Loss: 1.0267, Train Acc: 1.13%, Val Acc: 4.50%
# Epoch 44/200, Train Loss: 1.0535, Val Loss: 1.0159, Train Acc: 2.26%, Val Acc: 4.50%
# Epoch 45/200, Train Loss: 1.0556, Val Loss: 1.0221, Train Acc: 1.35%, Val Acc: 4.50%
# Epoch 46/200, Train Loss: 1.0524, Val Loss: 1.0141, Train Acc: 2.48%, Val Acc: 0.00%
# Epoch 47/200, Train Loss: 1.0455, Val Loss: 1.0010, Train Acc: 0.90%, Val Acc: 0.00%
# Epoch 48/200, Train Loss: 1.0503, Val Loss: 1.0594, Train Acc: 1.47%, Val Acc: 0.00%
# Epoch 49/200, Train Loss: 1.0522, Val Loss: 1.0296, Train Acc: 0.79%, Val Acc: 0.00%
# Epoch 50/200, Train Loss: 1.0493, Val Loss: 0.9990, Train Acc: 1.92%, Val Acc: 0.90%
# Epoch 51/200, Train Loss: 1.0395, Val Loss: 0.9996, Train Acc: 1.24%, Val Acc: 0.00%
# Epoch 52/200, Train Loss: 1.0389, Val Loss: 1.0422, Train Acc: 1.02%, Val Acc: 4.50%
# Epoch 53/200, Train Loss: 1.0437, Val Loss: 0.9441, Train Acc: 1.24%, Val Acc: 7.21%
# Epoch 54/200, Train Loss: 1.0413, Val Loss: 0.9720, Train Acc: 1.02%, Val Acc: 1.80%
# Epoch 55/200, Train Loss: 1.0229, Val Loss: 1.1541, Train Acc: 1.81%, Val Acc: 2.70%
# Epoch 56/200, Train Loss: 1.0486, Val Loss: 0.9785, Train Acc: 1.92%, Val Acc: 0.00%
# Epoch 57/200, Train Loss: 1.0224, Val Loss: 0.9402, Train Acc: 1.47%, Val Acc: 1.80%
# Epoch 58/200, Train Loss: 1.0121, Val Loss: 0.9500, Train Acc: 2.60%, Val Acc: 0.90%
# Epoch 59/200, Train Loss: 1.0093, Val Loss: 0.9201, Train Acc: 1.47%, Val Acc: 4.50%
# Epoch 60/200, Train Loss: 0.9882, Val Loss: 0.9316, Train Acc: 4.40%, Val Acc: 5.41%
# Epoch 61/200, Train Loss: 0.9827, Val Loss: 0.8750, Train Acc: 2.60%, Val Acc: 4.50%
# Epoch 62/200, Train Loss: 0.9757, Val Loss: 0.8601, Train Acc: 4.40%, Val Acc: 6.31%
# Epoch 63/200, Train Loss: 0.9523, Val Loss: 0.8919, Train Acc: 3.95%, Val Acc: 9.01%
# Epoch 64/200, Train Loss: 0.9800, Val Loss: 0.8534, Train Acc: 3.95%, Val Acc: 6.31%
# Epoch 65/200, Train Loss: 0.9532, Val Loss: 0.8778, Train Acc: 5.30%, Val Acc: 3.60%
# Epoch 66/200, Train Loss: 0.9237, Val Loss: 0.7850, Train Acc: 5.42%, Val Acc: 9.01%
# Epoch 67/200, Train Loss: 0.9407, Val Loss: 0.8058, Train Acc: 5.87%, Val Acc: 9.01%
# Epoch 68/200, Train Loss: 0.9131, Val Loss: 0.7650, Train Acc: 4.97%, Val Acc: 9.01%
# Epoch 69/200, Train Loss: 0.9015, Val Loss: 0.7617, Train Acc: 7.34%, Val Acc: 6.31%
# Epoch 70/200, Train Loss: 0.9223, Val Loss: 0.7719, Train Acc: 7.22%, Val Acc: 6.31%
# Epoch 71/200, Train Loss: 0.8846, Val Loss: 0.7458, Train Acc: 8.01%, Val Acc: 8.11%
# Epoch 72/200, Train Loss: 0.8542, Val Loss: 0.7413, Train Acc: 8.92%, Val Acc: 5.41%
# Epoch 73/200, Train Loss: 0.8531, Val Loss: 0.7251, Train Acc: 8.92%, Val Acc: 9.91%
# Epoch 74/200, Train Loss: 0.8404, Val Loss: 0.7184, Train Acc: 10.38%, Val Acc: 7.21%
# Epoch 75/200, Train Loss: 0.8451, Val Loss: 0.7124, Train Acc: 9.26%, Val Acc: 8.11%
# Epoch 76/200, Train Loss: 0.8224, Val Loss: 0.7157, Train Acc: 10.27%, Val Acc: 9.91%
# Epoch 77/200, Train Loss: 0.8133, Val Loss: 0.6864, Train Acc: 9.37%, Val Acc: 13.51%
# Epoch 78/200, Train Loss: 0.8151, Val Loss: 0.6787, Train Acc: 9.59%, Val Acc: 16.22%
# Epoch 79/200, Train Loss: 0.8213, Val Loss: 0.6799, Train Acc: 8.13%, Val Acc: 10.81%
# Epoch 80/200, Train Loss: 0.8140, Val Loss: 0.6518, Train Acc: 11.40%, Val Acc: 13.51%
# Epoch 81/200, Train Loss: 0.7940, Val Loss: 0.6632, Train Acc: 10.72%, Val Acc: 16.22%
# Epoch 82/200, Train Loss: 0.7869, Val Loss: 0.6439, Train Acc: 10.38%, Val Acc: 20.72%
# Epoch 83/200, Train Loss: 0.7944, Val Loss: 0.6711, Train Acc: 11.29%, Val Acc: 14.41%
# Epoch 84/200, Train Loss: 0.7679, Val Loss: 0.6394, Train Acc: 13.32%, Val Acc: 19.82%
# Epoch 85/200, Train Loss: 0.7732, Val Loss: 0.6093, Train Acc: 12.64%, Val Acc: 21.62%
# Epoch 86/200, Train Loss: 0.7559, Val Loss: 0.6347, Train Acc: 16.82%, Val Acc: 19.82%
# Epoch 87/200, Train Loss: 0.7521, Val Loss: 0.6107, Train Acc: 15.91%, Val Acc: 19.82%
# Epoch 88/200, Train Loss: 0.7517, Val Loss: 0.6139, Train Acc: 15.46%, Val Acc: 20.72%
# Epoch 89/200, Train Loss: 0.7294, Val Loss: 0.6591, Train Acc: 18.06%, Val Acc: 12.61%
# Epoch 90/200, Train Loss: 0.7239, Val Loss: 0.5903, Train Acc: 17.61%, Val Acc: 22.52%
# Epoch 91/200, Train Loss: 0.7417, Val Loss: 0.6008, Train Acc: 16.03%, Val Acc: 16.22%
# Epoch 92/200, Train Loss: 0.7272, Val Loss: 0.5697, Train Acc: 15.69%, Val Acc: 27.93%
# Epoch 93/200, Train Loss: 0.6998, Val Loss: 0.5898, Train Acc: 18.62%, Val Acc: 25.23%
# Epoch 94/200, Train Loss: 0.7016, Val Loss: 0.5563, Train Acc: 20.32%, Val Acc: 28.83%
# Epoch 95/200, Train Loss: 0.7051, Val Loss: 0.5559, Train Acc: 18.40%, Val Acc: 24.32%
# Epoch 96/200, Train Loss: 0.7165, Val Loss: 0.5252, Train Acc: 18.06%, Val Acc: 24.32%
# Epoch 97/200, Train Loss: 0.6798, Val Loss: 0.5123, Train Acc: 20.77%, Val Acc: 26.13%
# Epoch 98/200, Train Loss: 0.6821, Val Loss: 0.5135, Train Acc: 18.85%, Val Acc: 27.93%
# Epoch 99/200, Train Loss: 0.6789, Val Loss: 0.5284, Train Acc: 20.54%, Val Acc: 29.73%
# Epoch 100/200, Train Loss: 0.6628, Val Loss: 0.4721, Train Acc: 22.46%, Val Acc: 32.43%
# Epoch 101/200, Train Loss: 0.6198, Val Loss: 0.4567, Train Acc: 24.15%, Val Acc: 28.83%
# Epoch 102/200, Train Loss: 0.6389, Val Loss: 0.4554, Train Acc: 20.99%, Val Acc: 30.63%
# Epoch 103/200, Train Loss: 0.6300, Val Loss: 0.4347, Train Acc: 21.90%, Val Acc: 31.53%
# Epoch 104/200, Train Loss: 0.6377, Val Loss: 0.4318, Train Acc: 21.11%, Val Acc: 35.14%
# Epoch 105/200, Train Loss: 0.6028, Val Loss: 0.4184, Train Acc: 23.81%, Val Acc: 34.23%
# Epoch 106/200, Train Loss: 0.6028, Val Loss: 0.4473, Train Acc: 25.85%, Val Acc: 32.43%
# Epoch 107/200, Train Loss: 0.5983, Val Loss: 0.3852, Train Acc: 24.60%, Val Acc: 33.33%
# Epoch 108/200, Train Loss: 0.6156, Val Loss: 0.3961, Train Acc: 24.27%, Val Acc: 31.53%
# Epoch 109/200, Train Loss: 0.5881, Val Loss: 0.3770, Train Acc: 28.22%, Val Acc: 33.33%
# Epoch 110/200, Train Loss: 0.5643, Val Loss: 0.3824, Train Acc: 28.89%, Val Acc: 36.04%
# Epoch 111/200, Train Loss: 0.5624, Val Loss: 0.3425, Train Acc: 26.75%, Val Acc: 42.34%
# Epoch 112/200, Train Loss: 0.5565, Val Loss: 0.3765, Train Acc: 28.89%, Val Acc: 38.74%
# Epoch 113/200, Train Loss: 0.5524, Val Loss: 0.3450, Train Acc: 26.52%, Val Acc: 40.54%
# Epoch 114/200, Train Loss: 0.5653, Val Loss: 0.3648, Train Acc: 27.31%, Val Acc: 38.74%
# Epoch 115/200, Train Loss: 0.5440, Val Loss: 0.3626, Train Acc: 28.78%, Val Acc: 39.64%
# Epoch 116/200, Train Loss: 0.5229, Val Loss: 0.3297, Train Acc: 27.99%, Val Acc: 39.64%
# Epoch 117/200, Train Loss: 0.5178, Val Loss: 0.3347, Train Acc: 31.83%, Val Acc: 40.54%
# Epoch 118/200, Train Loss: 0.5070, Val Loss: 0.3276, Train Acc: 32.73%, Val Acc: 44.14%
# Epoch 119/200, Train Loss: 0.5157, Val Loss: 0.3374, Train Acc: 29.46%, Val Acc: 45.95%
# Epoch 120/200, Train Loss: 0.5085, Val Loss: 0.2936, Train Acc: 31.04%, Val Acc: 45.05%
# Epoch 121/200, Train Loss: 0.5089, Val Loss: 0.2896, Train Acc: 32.73%, Val Acc: 48.65%
# Epoch 122/200, Train Loss: 0.5006, Val Loss: 0.3183, Train Acc: 33.75%, Val Acc: 43.24%
# Epoch 123/200, Train Loss: 0.4788, Val Loss: 0.3145, Train Acc: 31.72%, Val Acc: 47.75%
# Epoch 124/200, Train Loss: 0.4592, Val Loss: 0.2945, Train Acc: 35.10%, Val Acc: 48.65%
# Epoch 125/200, Train Loss: 0.4454, Val Loss: 0.2957, Train Acc: 34.42%, Val Acc: 48.65%
# Epoch 126/200, Train Loss: 0.4776, Val Loss: 0.2891, Train Acc: 34.42%, Val Acc: 49.55%
# Epoch 127/200, Train Loss: 0.4596, Val Loss: 0.2791, Train Acc: 33.86%, Val Acc: 50.45%
# Epoch 128/200, Train Loss: 0.4351, Val Loss: 0.2686, Train Acc: 36.23%, Val Acc: 54.05%
# Epoch 129/200, Train Loss: 0.4257, Val Loss: 0.2604, Train Acc: 38.37%, Val Acc: 51.35%
# Epoch 130/200, Train Loss: 0.4334, Val Loss: 0.2402, Train Acc: 36.46%, Val Acc: 54.95%
# Epoch 131/200, Train Loss: 0.4268, Val Loss: 0.2750, Train Acc: 38.26%, Val Acc: 54.05%
# Epoch 132/200, Train Loss: 0.4551, Val Loss: 0.2409, Train Acc: 37.36%, Val Acc: 53.15%
# Epoch 133/200, Train Loss: 0.4340, Val Loss: 0.2494, Train Acc: 35.44%, Val Acc: 49.55%
# Epoch 134/200, Train Loss: 0.4340, Val Loss: 0.2324, Train Acc: 35.67%, Val Acc: 54.95%
# Epoch 135/200, Train Loss: 0.4072, Val Loss: 0.2592, Train Acc: 38.71%, Val Acc: 48.65%
# Epoch 136/200, Train Loss: 0.4242, Val Loss: 0.2452, Train Acc: 37.13%, Val Acc: 50.45%
# Epoch 137/200, Train Loss: 0.3998, Val Loss: 0.2368, Train Acc: 38.83%, Val Acc: 53.15%
# Epoch 138/200, Train Loss: 0.4054, Val Loss: 0.2271, Train Acc: 41.20%, Val Acc: 54.95%
# Epoch 139/200, Train Loss: 0.4007, Val Loss: 0.2262, Train Acc: 39.50%, Val Acc: 54.05%
# Epoch 140/200, Train Loss: 0.3710, Val Loss: 0.2430, Train Acc: 40.86%, Val Acc: 53.15%
# Epoch 141/200, Train Loss: 0.4063, Val Loss: 0.2420, Train Acc: 39.95%, Val Acc: 52.25%
# Epoch 142/200, Train Loss: 0.3886, Val Loss: 0.2169, Train Acc: 41.53%, Val Acc: 57.66%
# Epoch 143/200, Train Loss: 0.3920, Val Loss: 0.2050, Train Acc: 41.53%, Val Acc: 52.25%
# Epoch 144/200, Train Loss: 0.3775, Val Loss: 0.2182, Train Acc: 40.63%, Val Acc: 56.76%
# Epoch 145/200, Train Loss: 0.3769, Val Loss: 0.2176, Train Acc: 42.10%, Val Acc: 52.25%
# Epoch 146/200, Train Loss: 0.3602, Val Loss: 0.2225, Train Acc: 43.45%, Val Acc: 54.95%
# Epoch 147/200, Train Loss: 0.3564, Val Loss: 0.2168, Train Acc: 44.13%, Val Acc: 57.66%
# Epoch 148/200, Train Loss: 0.3709, Val Loss: 0.2099, Train Acc: 44.81%, Val Acc: 60.36%
# Epoch 149/200, Train Loss: 0.3561, Val Loss: 0.1928, Train Acc: 45.37%, Val Acc: 60.36%
# Epoch 150/200, Train Loss: 0.3640, Val Loss: 0.1902, Train Acc: 43.00%, Val Acc: 60.36%
# Epoch 151/200, Train Loss: 0.3467, Val Loss: 0.2059, Train Acc: 44.92%, Val Acc: 63.96%
# Epoch 152/200, Train Loss: 0.3408, Val Loss: 0.1925, Train Acc: 45.49%, Val Acc: 57.66%
# Epoch 153/200, Train Loss: 0.3376, Val Loss: 0.1890, Train Acc: 46.16%, Val Acc: 63.06%
# Epoch 154/200, Train Loss: 0.3401, Val Loss: 0.2249, Train Acc: 47.63%, Val Acc: 53.15%
# Epoch 155/200, Train Loss: 0.3493, Val Loss: 0.2022, Train Acc: 45.82%, Val Acc: 55.86%
# Epoch 156/200, Train Loss: 0.3474, Val Loss: 0.1884, Train Acc: 44.92%, Val Acc: 56.76%
# Epoch 157/200, Train Loss: 0.3408, Val Loss: 0.1811, Train Acc: 48.42%, Val Acc: 63.96%
# Epoch 158/200, Train Loss: 0.3419, Val Loss: 0.1902, Train Acc: 48.31%, Val Acc: 63.06%
# Epoch 159/200, Train Loss: 0.3250, Val Loss: 0.1798, Train Acc: 48.65%, Val Acc: 66.67%
# Epoch 160/200, Train Loss: 0.3333, Val Loss: 0.1804, Train Acc: 46.84%, Val Acc: 65.77%
# Epoch 161/200, Train Loss: 0.3139, Val Loss: 0.1889, Train Acc: 48.98%, Val Acc: 66.67%
# Epoch 162/200, Train Loss: 0.3264, Val Loss: 0.1792, Train Acc: 47.97%, Val Acc: 68.47%
# Epoch 163/200, Train Loss: 0.3280, Val Loss: 0.1848, Train Acc: 48.19%, Val Acc: 67.57%
# Epoch 164/200, Train Loss: 0.3127, Val Loss: 0.1976, Train Acc: 46.95%, Val Acc: 65.77%
# Epoch 165/200, Train Loss: 0.3339, Val Loss: 0.1980, Train Acc: 46.73%, Val Acc: 65.77%
# Epoch 166/200, Train Loss: 0.3203, Val Loss: 0.1738, Train Acc: 48.19%, Val Acc: 70.27%
# Epoch 167/200, Train Loss: 0.3217, Val Loss: 0.1655, Train Acc: 48.31%, Val Acc: 68.47%
# Epoch 168/200, Train Loss: 0.2881, Val Loss: 0.1671, Train Acc: 51.81%, Val Acc: 67.57%
# Epoch 169/200, Train Loss: 0.3097, Val Loss: 0.1777, Train Acc: 49.89%, Val Acc: 66.67%
# Epoch 170/200, Train Loss: 0.2857, Val Loss: 0.1762, Train Acc: 52.48%, Val Acc: 68.47%
# Epoch 171/200, Train Loss: 0.2934, Val Loss: 0.1953, Train Acc: 49.77%, Val Acc: 66.67%
# Epoch 172/200, Train Loss: 0.2980, Val Loss: 0.1746, Train Acc: 52.14%, Val Acc: 71.17%
# Epoch 173/200, Train Loss: 0.3072, Val Loss: 0.1972, Train Acc: 51.69%, Val Acc: 68.47%
# Epoch 174/200, Train Loss: 0.2869, Val Loss: 0.1540, Train Acc: 53.50%, Val Acc: 72.97%
# Epoch 175/200, Train Loss: 0.3013, Val Loss: 0.1676, Train Acc: 51.02%, Val Acc: 67.57%
# Epoch 176/200, Train Loss: 0.3108, Val Loss: 0.2048, Train Acc: 51.24%, Val Acc: 63.96%
# Epoch 177/200, Train Loss: 0.3001, Val Loss: 0.1792, Train Acc: 52.60%, Val Acc: 63.96%
# Epoch 178/200, Train Loss: 0.2911, Val Loss: 0.1725, Train Acc: 52.93%, Val Acc: 66.67%
# Epoch 179/200, Train Loss: 0.2994, Val Loss: 0.1826, Train Acc: 50.56%, Val Acc: 65.77%
# Epoch 180/200, Train Loss: 0.2840, Val Loss: 0.1667, Train Acc: 52.26%, Val Acc: 69.37%
# Epoch 181/200, Train Loss: 0.2627, Val Loss: 0.1936, Train Acc: 54.85%, Val Acc: 65.77%
# Epoch 182/200, Train Loss: 0.2953, Val Loss: 0.1572, Train Acc: 50.90%, Val Acc: 72.07%
# Epoch 183/200, Train Loss: 0.2854, Val Loss: 0.1689, Train Acc: 54.06%, Val Acc: 69.37%
# Epoch 184/200, Train Loss: 0.2603, Val Loss: 0.1789, Train Acc: 56.55%, Val Acc: 66.67%
# Epoch 185/200, Train Loss: 0.2440, Val Loss: 0.1552, Train Acc: 58.13%, Val Acc: 73.87%
# Epoch 186/200, Train Loss: 0.2690, Val Loss: 0.1692, Train Acc: 57.22%, Val Acc: 73.87%
# Epoch 187/200, Train Loss: 0.2874, Val Loss: 0.1604, Train Acc: 55.08%, Val Acc: 72.97%
# Epoch 188/200, Train Loss: 0.2792, Val Loss: 0.1736, Train Acc: 54.06%, Val Acc: 69.37%
# Epoch 189/200, Train Loss: 0.2548, Val Loss: 0.1784, Train Acc: 57.22%, Val Acc: 68.47%
# Epoch 190/200, Train Loss: 0.2694, Val Loss: 0.1664, Train Acc: 58.92%, Val Acc: 73.87%
# Epoch 191/200, Train Loss: 0.2621, Val Loss: 0.1545, Train Acc: 57.45%, Val Acc: 71.17%
# Epoch 192/200, Train Loss: 0.2596, Val Loss: 0.1679, Train Acc: 54.51%, Val Acc: 71.17%
# Epoch 193/200, Train Loss: 0.2575, Val Loss: 0.1765, Train Acc: 56.77%, Val Acc: 69.37%
# Epoch 194/200, Train Loss: 0.2755, Val Loss: 0.1990, Train Acc: 55.08%, Val Acc: 70.27%
# Epoch 195/200, Train Loss: 0.2634, Val Loss: 0.1606, Train Acc: 57.56%, Val Acc: 71.17%
# Epoch 196/200, Train Loss: 0.2622, Val Loss: 0.1542, Train Acc: 53.95%, Val Acc: 72.07%
# Epoch 197/200, Train Loss: 0.2619, Val Loss: 0.1662, Train Acc: 55.76%, Val Acc: 71.17%
# Epoch 198/200, Train Loss: 0.2579, Val Loss: 0.1520, Train Acc: 58.24%, Val Acc: 74.77%
# Epoch 199/200, Train Loss: 0.2409, Val Loss: 0.1601, Train Acc: 57.45%, Val Acc: 72.97%
# Epoch 200/200, Train Loss: 0.2541, Val Loss: 0.1606, Train Acc: 56.66%, Val Acc: 70.27%

# %%
import torch
from PIL import Image
from torchvision import transforms

# Define character mapping for subject codes
char_map = {i: str(i-1) for i in range(1, 11)}  # 1-10 -> '0'-'9'
char_map.update({i: chr(i - 11 + ord('A')) for i in range(11, 37)})  # 11-36 -> 'A'-'Z'

# Assuming val_test_transform is defined as in training (update if different)
val_test_transform = transforms.Compose([
    transforms.Resize((32, 128)),
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))
])

def decode_predictions(outputs):
    outputs = outputs.softmax(2).argmax(2)  # (T, N) -> e.g., (32, N)
    batch_size = outputs.size(1)
    decoded = []
    for b in range(batch_size):
        seq = outputs[:, b].cpu().numpy()  # (T,)
        prev = -1
        result = []
        for s in seq:
            if s != 0 and s != prev:
                char = char_map.get(s, '')
                if char:
                    result.append(char)
            prev = s
        decoded.append(''.join(result))
    return decoded

# Test accuracy calculation
model.eval()
correct = 0
total = 0
with torch.no_grad():
    for images, targets in test_loader:
        images = images.to(device)
        outputs = model(images)  # (T, N, 37)
        predictions = decode_predictions(outputs)
        target_labels = [''.join([char_map[d.item()] for d in t]) for t in targets]
        for pred, target in zip(predictions, target_labels):
            if pred == target:
                correct += 1
            total += 1
print(f"Test Accuracy: {correct/total*100:.2f}%")

def predict_subject_code(model, image_path, device, transform):
    image = Image.open(image_path).convert('L')
    image = transform(image)
    image = image.unsqueeze(0)  # (1, 1, 32, 128)
    model.eval()
    with torch.no_grad():
        image = image.to(device)
        output = model(image)  # (T, 1, 37), e.g., (32, 1, 37)
        output = output.squeeze(1)  # (T, 37)
        output = output.softmax(1).argmax(1)  # (T,)
        seq = output.cpu().numpy()
        prev = -1
        result = []
        for s in seq:
            if s != 0 and s != prev:
                char = char_map.get(s, '')
                if char:
                    result.append(char)
            prev = s
    return ''.join(result)

# Test with your image
image_path = 'subject_code_2.jpg'  # Replace with your image path
predicted_code = predict_subject_code(model, image_path, device, val_test_transform)
print(f"Predicted Subject Code: {predicted_code}")
# Out:
# Test Accuracy: 78.38%
# Predicted Subject Code: 19CS404
